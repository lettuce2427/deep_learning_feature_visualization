# %%
from scipy.io import loadmat
import numpy as np
import random
def load_data(file_path):
    data = loadmat(file_path)
    data_x = data['X']
    data_y = data['y']
    data_y = np.where(data_y==10, [0],data_y)
    num_data = data_x.shape[3]
    return_data = []
    for i in range(num_data):
        return_data.append(data_x[:,:,:,i])
    return_label = to_categorical(data_y)
    return np.array(return_data), return_label
def to_categorical(y, num_classes=None):
    """
    把输入的标签变成one-hot形式
    """
    y = np.array(y, dtype='int').ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes))
    categorical[np.arange(n), y] = 1
    return categorical
def get_batch(data, label, batch_size):
    list = [i for i in range(label.shape[0])]
    random.shuffle(list)
    return_data = data[list[:batch_size],:,:,:]
    return_label = label[list[:batch_size],:]
    return return_data, return_label

# %%
import tensorflow as tf
from tensorflow.contrib import slim
import numpy as np
class CNN():
    def __init__(self, input_size, input_depth, num_classes, learning_rate, is_training=True):
        graph = tf.Graph()
        with graph.as_default():
            self.x = tf.placeholder(tf.float32, shape=[None, input_size, input_size, input_depth])
            self.y_ = tf.placeholder(tf.float32, shape=[None, num_classes])
            self.keep_prob = tf.placeholder(tf.float32)
            self.conv1 = slim.conv2d(self.x, 32, [5, 5], scope='convolution_1')
            self.pool1 = slim.max_pool2d(self.conv1, [2, 2], 2, scope='pool1')
            self.conv2 = slim.conv2d(self.pool1, 64, [5, 5], scope='convolution_2')
            self.pool2 = slim.max_pool2d(self.conv2, [2, 2], 2, scope='pool2')
            flatten = slim.flatten(self.pool2)
            self.fc3 = slim.fully_connected(flatten, 1024, scope='fc3')
            drop_out = slim.dropout(self.fc3, self.keep_prob, is_training=is_training, scope='dropout3')
            self.y = slim.fully_connected(drop_out, num_classes, activation_fn=None, scope='fc4')
            self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=self.y, labels=self.y_), name='loss')
            self.train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
            self.predicted = tf.argmax(self.y, 1)
            self.accuracy = tf.reduce_mean(tf.cast(tf.equal(self.predicted, tf.argmax(self.y_, 1)), tf.float32), name='acc')
            init = tf.global_variables_initializer()
            self.saver = tf.train.Saver()
        self.sess = tf.Session(graph=graph)
        self.sess.run([init])

    # conv层的显示
    # 格式是 （？，size, size, depth)
    def show_conv(self, out, fig):
        show_row = out.shape[0]
        show_col = out.shape[3]
        for row in range(show_row):
            for col in range(show_col):
                ax = fig.add_subplot(show_row, show_col, (row * show_col + col + 1))
                show_img = out[row, :, :, col]
                ax.imshow(show_img, )
                ax.axis('off')
    # fc 层显示函数
    # 数据格式是：（？， size)
    def show_fc(self, out, fig):
        show_row = out.shape[0]
        show_size = int(np.sqrt(out.shape[1]))
        for row in range(show_row):
            ax = fig.add_subplot(show_row, 1, row + 1)
            show_img = out[row, :]
            show_img = np.reshape(show_img, [show_size, show_size])
            ax.imshow(show_img)
            ax.axis('off')

# %%
import tensorflow as tf
from tensorflow.contrib import slim
import numpy as np
class CNN():
    def __init__(self, input_size, input_depth, num_classes, learning_rate):
        self.input_size = input_size
        graph = tf.Graph()
        with graph.as_default():
            self.x = tf.placeholder(tf.float32, shape=[None, input_size, input_size, input_depth])
            self.y_ = tf.placeholder(tf.float32, shape=[None, num_classes])
            self.keep_prob = tf.placeholder(tf.float32)
            # 第一层卷积层
            self.W_conv1 = self.__weight_variable([5, 5, input_depth, 32])
            self.b_conv1 = self.__bias_variable([32])
            self.h_conv1 = tf.nn.relu(self.__conv2d(self.x, self.W_conv1) + self.b_conv1)
            self.h_pool1 = self.__max_pool_2x2(self.h_conv1)

            # 第二层卷积层
            self.W_conv2 = self.__weight_variable([5, 5, 32, 64])
            self.b_conv2 = self.__bias_variable([64])
            self.h_conv2 = tf.nn.relu(self.__conv2d(self.h_pool1, self.W_conv2) + self.b_conv2)
            self.h_pool2 = self.__max_pool_2x2(self.h_conv2)

            flatten = slim.flatten(self.h_pool2)
            self.fc3 = slim.fully_connected(flatten, 1024, scope='fc3')
            drop_out = slim.dropout(self.fc3, self.keep_prob, is_training=True, scope='dropout3')
            self.y = slim.fully_connected(drop_out, num_classes, activation_fn=None, scope='fc4')
            self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=self.y, labels=self.y_),
                                       name='loss')
            self.train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(self.loss)
            self.predicted = tf.argmax(self.y, 1)
            self.accuracy = tf.reduce_mean(tf.cast(tf.equal(self.predicted, tf.argmax(self.y_, 1)), tf.float32),
                                           name='acc')
            init = tf.global_variables_initializer()
            self.saver = tf.train.Saver()
        self.sess = tf.Session(graph=graph)
        self.sess.run([init])

    def __weight_variable(self, shape):
        initial = tf.truncated_normal(shape, stddev=0.1)
        return tf.Variable(initial)

    def __bias_variable(self, shape):
        initial = tf.constant(0.1, shape=shape)
        return tf.Variable(initial)

    # 定义卷积操作
    def __conv2d(self, x, W):
        return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

    # 定义池化操作
    def __max_pool_2x2(self, x):
        return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
def show_conv1(fig, input_conv, input_kernel, input_size, depth):
    if depth==1:
        cmap_input = 'gray_r'
        cmap_conv = 'gray_r'
        shape = [input_size, input_size]
    if depth == 3:
        cmap_input = None
        cmap_conv = 'gray_r'
        shape = [input_size, input_size, depth]
    sess = tf.Session()
    show_conv_shape = [input_size, input_size]
    convs = [input_conv[:,:,:,i].reshape([1, input_size, input_size, 1]) for i in range(32)]
    kernels =[input_kernel[:,:,:,i].reshape([input_kernel.shape[0], input_kernel.shape[1], input_kernel.shape[2], 1]) for i in range(32)]
    deconv = []
    for i in range(32):
        deconv.append(tf.nn.conv2d_transpose(convs[i], filter=kernels[i], output_shape=[1, input_size, input_size, depth], strides=[1, 1, 1, 1], padding='SAME'))
    deconvs = sess.run([deconv])[0]
    deconv_count = 0
    conv_count = 0
    for row in range(8):
        for col in range(8):
            ax = fig.add_subplot(8, 8, row * 8 + col + 1)
            if col >= 4:
                ax.imshow(norm(deconvs[deconv_count].reshape(shape)), cmap=cmap_input)
                deconv_count = deconv_count + 1
            else:
                ax.imshow(convs[conv_count].reshape(show_conv_shape), cmap=cmap_conv)
                conv_count = conv_count + 1
            ax.axis('off')

def show_conv2(fig, input_conv, input_kernel1, input_kernel2, input_size, depth):
    if depth==1:
        cmap_input = 'gray_r'
        cmap_conv = 'gray_r'
        shape = [input_size, input_size]
    if depth == 3:
        cmap_input = None
        cmap_conv = 'gray_r'
        shape = [input_size, input_size, depth]
    conv_shape = [input_conv.shape[1], input_conv.shape[2]]
    sess = tf.Session()
    conv_2_shape = [1, input_conv.shape[1], input_conv.shape[2], 1]
    conv_2_kernel_shape = [input_kernel2.shape[0], input_kernel2.shape[1], input_kernel2.shape[2], 1]
    deconv_2_shape = [1, input_size, input_size, input_kernel2.shape[2]]

    convs = [input_conv[:, :, :, i].reshape(conv_2_shape) for i in range(64)]
    kernels_2 = [input_kernel2[:, :, :, i].reshape(conv_2_kernel_shape) for i in range(64)]

    deconv_2_to_1 = []
    for i in range(64):
        deconv_2_to_1.append(tf.nn.conv2d_transpose(convs[i], filter=kernels_2[i], output_shape=deconv_2_shape,
                                             strides=[1, 2, 2, 1], padding='SAME'))
    deconv =[tf.nn.conv2d_transpose(deconv_2_to_1[i],filter=input_kernel1, output_shape=[1, input_size, input_size, depth],strides=[1, 1, 1, 1], padding='SAME') for i in range(len(deconv_2_to_1))]
    deconvs = sess.run([deconv])[0]
    print(len(deconv))
    deconv_count = 0
    conv_count = 0
    for row in range(8):
        for col in range(16):
            ax = fig.add_subplot(8, 16, row * 16 + col + 1)
            if col >= 8:
                ax.imshow(norm(deconvs[deconv_count].reshape(shape)), cmap=cmap_input)
                deconv_count = deconv_count + 1
            else:
                ax.imshow(convs[conv_count].reshape(conv_shape), cmap=cmap_conv)
                conv_count = conv_count + 1
            ax.axis('off')
def norm(input_data):
    return (input_data-np.min(input_data))/(np.max(input_data)-np.min(input_data))

# %%
from cnn2 import CNN
from data import *
file_path = 'train_32x32.mat'
data_x, data_y = load_data(file_path)

input_size = 32
depth = 3
num_classes = 10
learning_rate = 1e-4
model_dir = './svhn_model/model.ckpt'
max_step = 2000

cnn = CNN(input_size, depth, num_classes, learning_rate)
for i in range(max_step):
    batch_x, batch_y = get_batch(data_x, data_y, 500)
    _, train_loss, train_acc = cnn.sess.run([cnn.train_op, cnn.loss, cnn.accuracy],
                                            feed_dict={cnn.x: batch_x, cnn.y_: batch_y, cnn.keep_prob: 0.5})
    print('step:{}, loss:{:0.3f}, acc:{:0.3f}'.format(i, train_loss, train_acc))
cnn.saver.save(cnn.sess, model_dir)

test_file_path = 'test_32x32.mat'
data_x, data_y = load_data(test_file_path)
test_acc = cnn.sess.run([cnn.accuracy], feed_dict={cnn.x:data_x, cnn.y_:data_y, cnn.keep_prob:1.0})
print('test acc:{}'.format(test_acc))
# Out:
# step:0, loss:369.563, acc:0.136
# step:1, loss:424.483, acc:0.104
# step:2, loss:371.037, acc:0.072
# step:3, loss:340.423, acc:0.100
# step:4, loss:328.892, acc:0.130
# step:5, loss:289.441, acc:0.144
# step:6, loss:273.280, acc:0.124
# step:7, loss:239.754, acc:0.122
# step:8, loss:245.569, acc:0.120
# step:9, loss:228.304, acc:0.104
# step:10, loss:213.585, acc:0.138
# step:11, loss:182.806, acc:0.116
# step:12, loss:178.922, acc:0.124
# step:13, loss:186.015, acc:0.126
# step:14, loss:172.506, acc:0.134
# step:15, loss:144.150, acc:0.146
# step:16, loss:135.220, acc:0.114
# step:17, loss:131.370, acc:0.116
# step:18, loss:127.486, acc:0.128
# step:19, loss:114.786, acc:0.106
# step:20, loss:107.080, acc:0.148
# step:21, loss:91.930, acc:0.124
# step:22, loss:86.784, acc:0.124
# step:23, loss:79.843, acc:0.174
# step:24, loss:76.071, acc:0.128
# step:25, loss:69.338, acc:0.132
# step:26, loss:58.151, acc:0.142
# step:27, loss:54.307, acc:0.142
# step:28, loss:54.979, acc:0.122
# step:29, loss:42.296, acc:0.162
# step:30, loss:40.330, acc:0.146
# step:31, loss:38.928, acc:0.146
# step:32, loss:33.317, acc:0.156
# step:33, loss:29.979, acc:0.150
# step:34, loss:26.325, acc:0.158
# step:35, loss:23.343, acc:0.150
# step:36, loss:19.445, acc:0.162
# step:37, loss:18.589, acc:0.142
# step:38, loss:15.522, acc:0.138
# step:39, loss:12.376, acc:0.182
# step:40, loss:12.630, acc:0.140
# step:41, loss:10.785, acc:0.200
# step:42, loss:9.932, acc:0.164
# step:43, loss:7.775, acc:0.162
# step:44, loss:6.891, acc:0.176
# step:45, loss:6.397, acc:0.156
# step:46, loss:5.824, acc:0.168
# step:47, loss:5.065, acc:0.180
# step:48, loss:5.548, acc:0.154
# step:49, loss:4.965, acc:0.158
# step:50, loss:4.604, acc:0.174
# step:51, loss:3.963, acc:0.168
# step:52, loss:4.120, acc:0.136
# step:53, loss:3.849, acc:0.206
# step:54, loss:3.966, acc:0.150
# step:55, loss:4.065, acc:0.152
# step:56, loss:3.350, acc:0.172
# step:57, loss:3.263, acc:0.184
# step:58, loss:3.147, acc:0.154
# step:59, loss:3.173, acc:0.172
# step:60, loss:3.275, acc:0.192
# step:61, loss:3.126, acc:0.158
# step:62, loss:3.094, acc:0.176
# step:63, loss:2.714, acc:0.198
# step:64, loss:3.002, acc:0.166
# step:65, loss:2.841, acc:0.186
# step:66, loss:2.857, acc:0.122
# step:67, loss:2.873, acc:0.180
# step:68, loss:2.868, acc:0.182
# step:69, loss:2.612, acc:0.166
# step:70, loss:2.911, acc:0.162
# step:71, loss:2.859, acc:0.204
# step:72, loss:2.609, acc:0.182
# step:73, loss:2.771, acc:0.190
# step:74, loss:2.677, acc:0.166
# step:75, loss:2.641, acc:0.174
# step:76, loss:2.700, acc:0.164
# step:77, loss:2.590, acc:0.188
# step:78, loss:2.468, acc:0.210
# step:79, loss:2.503, acc:0.208
# step:80, loss:2.574, acc:0.180
# step:81, loss:2.500, acc:0.176
# step:82, loss:2.472, acc:0.204
# step:83, loss:2.551, acc:0.160
# step:84, loss:2.548, acc:0.170
# step:85, loss:2.478, acc:0.188
# step:86, loss:2.542, acc:0.176
# step:87, loss:2.617, acc:0.166
# step:88, loss:2.523, acc:0.186
# step:89, loss:2.632, acc:0.172
# step:90, loss:2.444, acc:0.192
# step:91, loss:2.427, acc:0.242
# step:92, loss:2.464, acc:0.170
# step:93, loss:2.572, acc:0.190
# step:94, loss:2.538, acc:0.188
# step:95, loss:2.409, acc:0.162
# step:96, loss:2.447, acc:0.180
# step:97, loss:2.528, acc:0.194
# step:98, loss:2.543, acc:0.188
# step:99, loss:2.548, acc:0.184
# step:100, loss:2.486, acc:0.214
# step:101, loss:2.435, acc:0.168
# step:102, loss:2.400, acc:0.166
# step:103, loss:2.427, acc:0.184
# step:104, loss:2.573, acc:0.182
# step:105, loss:2.356, acc:0.160
# step:106, loss:2.502, acc:0.178
# step:107, loss:2.621, acc:0.144
# step:108, loss:2.454, acc:0.196
# step:109, loss:2.496, acc:0.188
# step:110, loss:2.423, acc:0.216
# step:111, loss:2.483, acc:0.156
# step:112, loss:2.402, acc:0.194
# step:113, loss:2.484, acc:0.182
# step:114, loss:2.423, acc:0.190
# step:115, loss:2.381, acc:0.190
# step:116, loss:2.374, acc:0.226
# step:117, loss:2.493, acc:0.212
# step:118, loss:2.426, acc:0.174
# step:119, loss:2.386, acc:0.156
# step:120, loss:2.351, acc:0.202
# step:121, loss:2.427, acc:0.220
# step:122, loss:2.403, acc:0.234
# step:123, loss:2.441, acc:0.174
# step:124, loss:2.345, acc:0.234
# step:125, loss:2.457, acc:0.174
# step:126, loss:2.373, acc:0.180
# step:127, loss:2.367, acc:0.166
# step:128, loss:2.425, acc:0.172
# step:129, loss:2.382, acc:0.192
# step:130, loss:2.367, acc:0.214
# step:131, loss:2.410, acc:0.208
# step:132, loss:2.389, acc:0.186
# step:133, loss:2.378, acc:0.188
# step:134, loss:2.408, acc:0.200
# step:135, loss:2.350, acc:0.222
# step:136, loss:2.374, acc:0.178
# step:137, loss:2.314, acc:0.178
# step:138, loss:2.363, acc:0.162
# step:139, loss:2.314, acc:0.188
# step:140, loss:2.350, acc:0.188
# step:141, loss:2.465, acc:0.164
# step:142, loss:2.354, acc:0.194
# step:143, loss:2.350, acc:0.216
# step:144, loss:2.348, acc:0.218
# step:145, loss:2.409, acc:0.170
# step:146, loss:2.404, acc:0.190
# step:147, loss:2.420, acc:0.200
# step:148, loss:2.346, acc:0.230
# step:149, loss:2.291, acc:0.224
# step:150, loss:2.330, acc:0.208
# step:151, loss:2.380, acc:0.220
# step:152, loss:2.359, acc:0.206
# step:153, loss:2.314, acc:0.200
# step:154, loss:2.372, acc:0.182
# step:155, loss:2.380, acc:0.174
# step:156, loss:2.303, acc:0.198
# step:157, loss:2.465, acc:0.180
# step:158, loss:2.341, acc:0.184
# step:159, loss:2.398, acc:0.198
# step:160, loss:2.348, acc:0.206
# step:161, loss:2.404, acc:0.178
# step:162, loss:2.381, acc:0.194
# step:163, loss:2.368, acc:0.174
# step:164, loss:2.345, acc:0.216
# step:165, loss:2.320, acc:0.186
# step:166, loss:2.334, acc:0.178
# step:167, loss:2.361, acc:0.192
# step:168, loss:2.386, acc:0.194
# step:169, loss:2.437, acc:0.180
# step:170, loss:2.363, acc:0.178
# step:171, loss:2.386, acc:0.180
# step:172, loss:2.335, acc:0.190
# step:173, loss:2.300, acc:0.166
# step:174, loss:2.359, acc:0.168
# step:175, loss:2.418, acc:0.218
# step:176, loss:2.450, acc:0.212
# step:177, loss:2.360, acc:0.186
# step:178, loss:2.371, acc:0.196
# step:179, loss:2.482, acc:0.174
# step:180, loss:2.385, acc:0.210
# step:181, loss:2.306, acc:0.152
# step:182, loss:2.349, acc:0.188
# step:183, loss:2.352, acc:0.210
# step:184, loss:2.411, acc:0.184
# step:185, loss:2.343, acc:0.184
# step:186, loss:2.319, acc:0.220
# step:187, loss:2.321, acc:0.198
# step:188, loss:2.333, acc:0.190
# step:189, loss:2.420, acc:0.182
# step:190, loss:2.422, acc:0.178
# step:191, loss:2.321, acc:0.190
# step:192, loss:2.305, acc:0.210
# step:193, loss:2.278, acc:0.198
# step:194, loss:2.353, acc:0.174
# step:195, loss:2.344, acc:0.182
# step:196, loss:2.425, acc:0.174
# step:197, loss:2.356, acc:0.186
# step:198, loss:2.392, acc:0.196
# step:199, loss:2.328, acc:0.214
# step:200, loss:2.339, acc:0.210
# step:201, loss:2.326, acc:0.206
# step:202, loss:2.295, acc:0.208
# step:203, loss:2.343, acc:0.212
# step:204, loss:2.309, acc:0.200
# step:205, loss:2.366, acc:0.190
# step:206, loss:2.341, acc:0.176
# step:207, loss:2.344, acc:0.154
# step:208, loss:2.345, acc:0.170
# step:209, loss:2.307, acc:0.186
# step:210, loss:2.303, acc:0.198
# step:211, loss:2.422, acc:0.198
# step:212, loss:2.315, acc:0.206
# step:213, loss:2.293, acc:0.184
# step:214, loss:2.322, acc:0.176
# step:215, loss:2.359, acc:0.188
# step:216, loss:2.317, acc:0.196
# step:217, loss:2.365, acc:0.194
# step:218, loss:2.355, acc:0.180
# step:219, loss:2.297, acc:0.194
# step:220, loss:2.334, acc:0.206
# step:221, loss:2.309, acc:0.190
# step:222, loss:2.338, acc:0.200
# step:223, loss:2.306, acc:0.176
# step:224, loss:2.352, acc:0.172
# step:225, loss:2.316, acc:0.160
# step:226, loss:2.401, acc:0.228
# step:227, loss:2.299, acc:0.184
# step:228, loss:2.363, acc:0.180
# step:229, loss:2.410, acc:0.192
# step:230, loss:2.369, acc:0.182
# step:231, loss:2.276, acc:0.224
# step:232, loss:2.392, acc:0.188
# step:233, loss:2.305, acc:0.190
# step:234, loss:2.372, acc:0.176
# step:235, loss:2.284, acc:0.196
# step:236, loss:2.374, acc:0.184
# step:237, loss:2.318, acc:0.220
# step:238, loss:2.331, acc:0.202
# step:239, loss:2.357, acc:0.196
# step:240, loss:2.299, acc:0.194
# step:241, loss:2.341, acc:0.196
# step:242, loss:2.316, acc:0.194
# step:243, loss:2.341, acc:0.208
# step:244, loss:2.344, acc:0.178
# step:245, loss:2.266, acc:0.202
# step:246, loss:2.328, acc:0.196
# step:247, loss:2.452, acc:0.180
# step:248, loss:2.310, acc:0.160
# step:249, loss:2.307, acc:0.188
# step:250, loss:2.347, acc:0.182
# step:251, loss:2.275, acc:0.186
# step:252, loss:2.275, acc:0.188
# step:253, loss:2.261, acc:0.220
# step:254, loss:2.351, acc:0.158
# step:255, loss:2.332, acc:0.202
# step:256, loss:2.318, acc:0.188
# step:257, loss:2.325, acc:0.194
# step:258, loss:2.393, acc:0.198
# step:259, loss:2.315, acc:0.200
# step:260, loss:2.285, acc:0.170
# step:261, loss:2.310, acc:0.198
# step:262, loss:2.276, acc:0.194
# step:263, loss:2.338, acc:0.222
# step:264, loss:2.299, acc:0.206
# step:265, loss:2.301, acc:0.194
# step:266, loss:2.320, acc:0.164
# step:267, loss:2.338, acc:0.188
# step:268, loss:2.293, acc:0.184
# step:269, loss:2.283, acc:0.210
# step:270, loss:2.325, acc:0.158
# step:271, loss:2.310, acc:0.188
# step:272, loss:2.269, acc:0.238
# step:273, loss:2.315, acc:0.236
# step:274, loss:2.291, acc:0.164
# step:275, loss:2.289, acc:0.244
# step:276, loss:2.340, acc:0.198
# step:277, loss:2.284, acc:0.166
# step:278, loss:2.272, acc:0.232
# step:279, loss:2.335, acc:0.208
# step:280, loss:2.379, acc:0.194
# step:281, loss:2.279, acc:0.234
# step:282, loss:2.343, acc:0.204
# step:283, loss:2.303, acc:0.198
# step:284, loss:2.274, acc:0.188
# step:285, loss:2.271, acc:0.194
# step:286, loss:2.321, acc:0.192
# step:287, loss:2.300, acc:0.212
# step:288, loss:2.358, acc:0.222
# step:289, loss:2.330, acc:0.192
# step:290, loss:2.393, acc:0.172
# step:291, loss:2.272, acc:0.200
# step:292, loss:2.268, acc:0.172
# step:293, loss:2.311, acc:0.194
# step:294, loss:2.273, acc:0.234
# step:295, loss:2.283, acc:0.220
# step:296, loss:2.317, acc:0.182
# step:297, loss:2.375, acc:0.174
# step:298, loss:2.304, acc:0.210
# step:299, loss:2.363, acc:0.174
# step:300, loss:2.304, acc:0.162
# step:301, loss:2.301, acc:0.226
# step:302, loss:2.316, acc:0.190
# step:303, loss:2.263, acc:0.208
# step:304, loss:2.275, acc:0.186
# step:305, loss:2.297, acc:0.160
# step:306, loss:2.353, acc:0.208
# step:307, loss:2.299, acc:0.208
# step:308, loss:2.272, acc:0.204
# step:309, loss:2.344, acc:0.202
# step:310, loss:2.293, acc:0.222
# step:311, loss:2.341, acc:0.184
# step:312, loss:2.316, acc:0.212
# step:313, loss:2.314, acc:0.184
# step:314, loss:2.245, acc:0.192
# step:315, loss:2.313, acc:0.180
# step:316, loss:2.267, acc:0.226
# step:317, loss:2.258, acc:0.192
# step:318, loss:2.275, acc:0.208
# step:319, loss:2.290, acc:0.204
# step:320, loss:2.364, acc:0.188
# step:321, loss:2.321, acc:0.190
# step:322, loss:2.234, acc:0.206
# step:323, loss:2.282, acc:0.202
# step:324, loss:2.270, acc:0.228
# step:325, loss:2.352, acc:0.182
# step:326, loss:2.274, acc:0.176
# step:327, loss:2.324, acc:0.238
# step:328, loss:2.273, acc:0.232
# step:329, loss:2.253, acc:0.218
# step:330, loss:2.272, acc:0.206
# step:331, loss:2.292, acc:0.206
# step:332, loss:2.229, acc:0.192
# step:333, loss:2.244, acc:0.194
# step:334, loss:2.280, acc:0.194
# step:335, loss:2.281, acc:0.182
# step:336, loss:2.302, acc:0.198
# step:337, loss:2.252, acc:0.198
# step:338, loss:2.272, acc:0.232
# step:339, loss:2.253, acc:0.210
# step:340, loss:2.356, acc:0.194
# step:341, loss:2.279, acc:0.232
# step:342, loss:2.290, acc:0.176
# step:343, loss:2.298, acc:0.234
# step:344, loss:2.275, acc:0.210
# step:345, loss:2.257, acc:0.192
# step:346, loss:2.256, acc:0.174
# step:347, loss:2.247, acc:0.218
# step:348, loss:2.312, acc:0.188
# step:349, loss:2.272, acc:0.230
# step:350, loss:2.359, acc:0.160
# step:351, loss:2.287, acc:0.172
# step:352, loss:2.275, acc:0.182
# step:353, loss:2.283, acc:0.192
# step:354, loss:2.288, acc:0.204
# step:355, loss:2.312, acc:0.222
# step:356, loss:2.257, acc:0.186
# step:357, loss:2.288, acc:0.188
# step:358, loss:2.335, acc:0.194
# step:359, loss:2.269, acc:0.220
# step:360, loss:2.265, acc:0.224
# step:361, loss:2.298, acc:0.212
# step:362, loss:2.331, acc:0.194
# step:363, loss:2.280, acc:0.200
# step:364, loss:2.322, acc:0.170
# step:365, loss:2.336, acc:0.192
# step:366, loss:2.225, acc:0.230
# step:367, loss:2.272, acc:0.190
# step:368, loss:2.303, acc:0.206
# step:369, loss:2.287, acc:0.210
# step:370, loss:2.273, acc:0.214
# step:371, loss:2.284, acc:0.174
# step:372, loss:2.271, acc:0.216
# step:373, loss:2.259, acc:0.188
# step:374, loss:2.266, acc:0.190
# step:375, loss:2.260, acc:0.210
# step:376, loss:2.303, acc:0.184
# step:377, loss:2.277, acc:0.222
# step:378, loss:2.303, acc:0.204
# step:379, loss:2.299, acc:0.184
# step:380, loss:2.287, acc:0.216
# step:381, loss:2.294, acc:0.206
# step:382, loss:2.282, acc:0.162
# step:383, loss:2.299, acc:0.226
# step:384, loss:2.298, acc:0.180
# step:385, loss:2.266, acc:0.164
# step:386, loss:2.298, acc:0.208
# step:387, loss:2.253, acc:0.174
# step:388, loss:2.244, acc:0.206
# step:389, loss:2.225, acc:0.230
# step:390, loss:2.251, acc:0.228
# step:391, loss:2.237, acc:0.196
# step:392, loss:2.266, acc:0.202
# step:393, loss:2.238, acc:0.212
# step:394, loss:2.289, acc:0.214
# step:395, loss:2.356, acc:0.192
# step:396, loss:2.266, acc:0.172
# step:397, loss:2.238, acc:0.220
# step:398, loss:2.249, acc:0.200
# step:399, loss:2.314, acc:0.174
# step:400, loss:2.252, acc:0.174
# step:401, loss:2.241, acc:0.194
# step:402, loss:2.302, acc:0.184
# step:403, loss:2.299, acc:0.162
# step:404, loss:2.228, acc:0.206
# step:405, loss:2.297, acc:0.180
# step:406, loss:2.257, acc:0.198
# step:407, loss:2.311, acc:0.208
# step:408, loss:2.247, acc:0.194
# step:409, loss:2.254, acc:0.208
# step:410, loss:2.256, acc:0.212
# step:411, loss:2.327, acc:0.234
# step:412, loss:2.240, acc:0.236
# step:413, loss:2.286, acc:0.172
# step:414, loss:2.210, acc:0.208
# step:415, loss:2.226, acc:0.210
# step:416, loss:2.236, acc:0.204
# step:417, loss:2.264, acc:0.186
# step:418, loss:2.235, acc:0.220
# step:419, loss:2.267, acc:0.214
# step:420, loss:2.239, acc:0.230
# step:421, loss:2.270, acc:0.222
# step:422, loss:2.247, acc:0.214
# step:423, loss:2.262, acc:0.234
# step:424, loss:2.235, acc:0.226
# step:425, loss:2.275, acc:0.206
# step:426, loss:2.212, acc:0.218
# step:427, loss:2.284, acc:0.228
# step:428, loss:2.234, acc:0.184
# step:429, loss:2.295, acc:0.184
# step:430, loss:2.242, acc:0.214
# step:431, loss:2.269, acc:0.188
# step:432, loss:2.277, acc:0.194
# step:433, loss:2.301, acc:0.232
# step:434, loss:2.283, acc:0.204
# step:435, loss:2.328, acc:0.174
# step:436, loss:2.248, acc:0.202
# step:437, loss:2.244, acc:0.220
# step:438, loss:2.227, acc:0.212
# step:439, loss:2.274, acc:0.200
# step:440, loss:2.235, acc:0.200
# step:441, loss:2.312, acc:0.172
# step:442, loss:2.263, acc:0.204
# step:443, loss:2.272, acc:0.186
# step:444, loss:2.239, acc:0.202
# step:445, loss:2.207, acc:0.236
# step:446, loss:2.274, acc:0.214
# step:447, loss:2.228, acc:0.208
# step:448, loss:2.215, acc:0.212
# step:449, loss:2.228, acc:0.224
# step:450, loss:2.280, acc:0.206
# step:451, loss:2.240, acc:0.216
# step:452, loss:2.236, acc:0.204
# step:453, loss:2.237, acc:0.202
# step:454, loss:2.224, acc:0.208
# step:455, loss:2.202, acc:0.210
# step:456, loss:2.261, acc:0.194
# step:457, loss:2.176, acc:0.230
# step:458, loss:2.238, acc:0.208
# step:459, loss:2.269, acc:0.210
# step:460, loss:2.266, acc:0.206
# step:461, loss:2.260, acc:0.176
# step:462, loss:2.253, acc:0.206
# step:463, loss:2.245, acc:0.210
# step:464, loss:2.263, acc:0.222
# step:465, loss:2.210, acc:0.250
# step:466, loss:2.239, acc:0.188
# step:467, loss:2.255, acc:0.220
# step:468, loss:2.256, acc:0.188
# step:469, loss:2.266, acc:0.182
# step:470, loss:2.302, acc:0.192
# step:471, loss:2.240, acc:0.196
# step:472, loss:2.252, acc:0.220
# step:473, loss:2.229, acc:0.222
# step:474, loss:2.258, acc:0.220
# step:475, loss:2.248, acc:0.190
# step:476, loss:2.266, acc:0.178
# step:477, loss:2.205, acc:0.198
# step:478, loss:2.262, acc:0.190
# step:479, loss:2.245, acc:0.234
# step:480, loss:2.275, acc:0.192
# step:481, loss:2.215, acc:0.208
# step:482, loss:2.269, acc:0.186
# step:483, loss:2.210, acc:0.198
# step:484, loss:2.236, acc:0.216
# step:485, loss:2.227, acc:0.214
# step:486, loss:2.245, acc:0.216
# step:487, loss:2.223, acc:0.192
# step:488, loss:2.243, acc:0.202
# step:489, loss:2.231, acc:0.202
# step:490, loss:2.214, acc:0.208
# step:491, loss:2.256, acc:0.194
# step:492, loss:2.210, acc:0.224
# step:493, loss:2.251, acc:0.184
# step:494, loss:2.240, acc:0.184
# step:495, loss:2.285, acc:0.158
# step:496, loss:2.227, acc:0.224
# step:497, loss:2.320, acc:0.218
# step:498, loss:2.227, acc:0.212
# step:499, loss:2.223, acc:0.206
# step:500, loss:2.202, acc:0.212
# step:501, loss:2.241, acc:0.250
# step:502, loss:2.242, acc:0.224
# step:503, loss:2.253, acc:0.212
# step:504, loss:2.224, acc:0.188
# step:505, loss:2.239, acc:0.224
# step:506, loss:2.242, acc:0.228
# step:507, loss:2.257, acc:0.216
# step:508, loss:2.218, acc:0.202
# step:509, loss:2.186, acc:0.242
# step:510, loss:2.247, acc:0.180
# step:511, loss:2.202, acc:0.232
# step:512, loss:2.212, acc:0.216
# step:513, loss:2.220, acc:0.226
# step:514, loss:2.221, acc:0.220
# step:515, loss:2.248, acc:0.200
# step:516, loss:2.223, acc:0.200
# step:517, loss:2.200, acc:0.226
# step:518, loss:2.238, acc:0.204
# step:519, loss:2.176, acc:0.228
# step:520, loss:2.234, acc:0.228
# step:521, loss:2.237, acc:0.210
# step:522, loss:2.179, acc:0.210
# step:523, loss:2.243, acc:0.216
# step:524, loss:2.258, acc:0.192
# step:525, loss:2.246, acc:0.210
# step:526, loss:2.165, acc:0.218
# step:527, loss:2.188, acc:0.206
# step:528, loss:2.184, acc:0.234
# step:529, loss:2.188, acc:0.224
# step:530, loss:2.221, acc:0.236
# step:531, loss:2.205, acc:0.226
# step:532, loss:2.174, acc:0.198
# step:533, loss:2.199, acc:0.246
# step:534, loss:2.199, acc:0.212
# step:535, loss:2.191, acc:0.198
# step:536, loss:2.160, acc:0.212
# step:537, loss:2.136, acc:0.232
# step:538, loss:2.199, acc:0.198
# step:539, loss:2.237, acc:0.214
# step:540, loss:2.166, acc:0.214
# step:541, loss:2.217, acc:0.202
# step:542, loss:2.169, acc:0.248
# step:543, loss:2.182, acc:0.226
# step:544, loss:2.220, acc:0.224
# step:545, loss:2.194, acc:0.218
# step:546, loss:2.214, acc:0.208
# step:547, loss:2.198, acc:0.210
# step:548, loss:2.292, acc:0.222
# step:549, loss:2.198, acc:0.220
# step:550, loss:2.142, acc:0.232
# step:551, loss:2.197, acc:0.194
# step:552, loss:2.273, acc:0.216
# step:553, loss:2.195, acc:0.208
# step:554, loss:2.171, acc:0.210
# step:555, loss:2.204, acc:0.222
# step:556, loss:2.213, acc:0.214
# step:557, loss:2.221, acc:0.252
# step:558, loss:2.241, acc:0.196
# step:559, loss:2.197, acc:0.208
# step:560, loss:2.201, acc:0.226
# step:561, loss:2.217, acc:0.208
# step:562, loss:2.216, acc:0.210
# step:563, loss:2.242, acc:0.212
# step:564, loss:2.227, acc:0.198
# step:565, loss:2.259, acc:0.192
# step:566, loss:2.206, acc:0.262
# step:567, loss:2.166, acc:0.212
# step:568, loss:2.214, acc:0.222
# step:569, loss:2.273, acc:0.208
# step:570, loss:2.158, acc:0.270
# step:571, loss:2.188, acc:0.222
# step:572, loss:2.216, acc:0.186
# step:573, loss:2.256, acc:0.228
# step:574, loss:2.223, acc:0.208
# step:575, loss:2.197, acc:0.200
# step:576, loss:2.143, acc:0.210
# step:577, loss:2.178, acc:0.216
# step:578, loss:2.171, acc:0.218
# step:579, loss:2.225, acc:0.210
# step:580, loss:2.213, acc:0.254
# step:581, loss:2.173, acc:0.232
# step:582, loss:2.264, acc:0.188
# step:583, loss:2.270, acc:0.212
# step:584, loss:2.200, acc:0.238
# step:585, loss:2.160, acc:0.246
# step:586, loss:2.188, acc:0.198
# step:587, loss:2.218, acc:0.218
# step:588, loss:2.164, acc:0.206
# step:589, loss:2.159, acc:0.222
# step:590, loss:2.181, acc:0.208
# step:591, loss:2.232, acc:0.194
# step:592, loss:2.244, acc:0.230
# step:593, loss:2.176, acc:0.226
# step:594, loss:2.200, acc:0.208
# step:595, loss:2.168, acc:0.222
# step:596, loss:2.203, acc:0.224
# step:597, loss:2.179, acc:0.246
# step:598, loss:2.208, acc:0.216
# step:599, loss:2.161, acc:0.232
# step:600, loss:2.175, acc:0.222
# step:601, loss:2.183, acc:0.212
# step:602, loss:2.194, acc:0.236
# step:603, loss:2.224, acc:0.222
# step:604, loss:2.208, acc:0.208
# step:605, loss:2.247, acc:0.246
# step:606, loss:2.244, acc:0.188
# step:607, loss:2.230, acc:0.218
# step:608, loss:2.151, acc:0.226
# step:609, loss:2.199, acc:0.220
# step:610, loss:2.188, acc:0.202
# step:611, loss:2.180, acc:0.214
# step:612, loss:2.155, acc:0.254
# step:613, loss:2.123, acc:0.214
# step:614, loss:2.151, acc:0.222
# step:615, loss:2.191, acc:0.200
# step:616, loss:2.174, acc:0.208
# step:617, loss:2.206, acc:0.212
# step:618, loss:2.198, acc:0.214
# step:619, loss:2.174, acc:0.198
# step:620, loss:2.173, acc:0.252
# step:621, loss:2.195, acc:0.214
# step:622, loss:2.168, acc:0.244
# step:623, loss:2.131, acc:0.250
# step:624, loss:2.198, acc:0.232
# step:625, loss:2.166, acc:0.224
# step:626, loss:2.114, acc:0.248
# step:627, loss:2.187, acc:0.196
# step:628, loss:2.210, acc:0.196
# step:629, loss:2.167, acc:0.238
# step:630, loss:2.161, acc:0.228
# step:631, loss:2.140, acc:0.198
# step:632, loss:2.143, acc:0.216
# step:633, loss:2.171, acc:0.234
# step:634, loss:2.153, acc:0.208
# step:635, loss:2.099, acc:0.264
# step:636, loss:2.164, acc:0.226
# step:637, loss:2.180, acc:0.206
# step:638, loss:2.200, acc:0.222
# step:639, loss:2.187, acc:0.220
# step:640, loss:2.112, acc:0.234
# step:641, loss:2.158, acc:0.204
# step:642, loss:2.180, acc:0.226
# step:643, loss:2.152, acc:0.226
# step:644, loss:2.244, acc:0.232
# step:645, loss:2.145, acc:0.214
# step:646, loss:2.185, acc:0.210
# step:647, loss:2.232, acc:0.206
# step:648, loss:2.141, acc:0.238
# step:649, loss:2.185, acc:0.204
# step:650, loss:2.260, acc:0.208
# step:651, loss:2.180, acc:0.196
# step:652, loss:2.167, acc:0.244
# step:653, loss:2.224, acc:0.218
# step:654, loss:2.137, acc:0.206
# step:655, loss:2.196, acc:0.240
# step:656, loss:2.167, acc:0.212
# step:657, loss:2.127, acc:0.250
# step:658, loss:2.169, acc:0.218
# step:659, loss:2.153, acc:0.258
# step:660, loss:2.239, acc:0.224
# step:661, loss:2.184, acc:0.220
# step:662, loss:2.125, acc:0.212
# step:663, loss:2.186, acc:0.232
# step:664, loss:2.154, acc:0.208
# step:665, loss:2.202, acc:0.252
# step:666, loss:2.154, acc:0.250
# step:667, loss:2.151, acc:0.226
# step:668, loss:2.174, acc:0.230
# step:669, loss:2.097, acc:0.248
# step:670, loss:2.185, acc:0.216
# step:671, loss:2.134, acc:0.242
# step:672, loss:2.110, acc:0.242
# step:673, loss:2.198, acc:0.242
# step:674, loss:2.161, acc:0.230
# step:675, loss:2.157, acc:0.198
# step:676, loss:2.167, acc:0.212
# step:677, loss:2.125, acc:0.234
# step:678, loss:2.217, acc:0.204
# step:679, loss:2.189, acc:0.228
# step:680, loss:2.200, acc:0.228
# step:681, loss:2.130, acc:0.232
# step:682, loss:2.186, acc:0.244
# step:683, loss:2.177, acc:0.220
# step:684, loss:2.173, acc:0.186
# step:685, loss:2.103, acc:0.246
# step:686, loss:2.130, acc:0.228
# step:687, loss:2.201, acc:0.190
# step:688, loss:2.152, acc:0.232
# step:689, loss:2.165, acc:0.210
# step:690, loss:2.186, acc:0.214
# step:691, loss:2.174, acc:0.216
# step:692, loss:2.158, acc:0.216
# step:693, loss:2.138, acc:0.234
# step:694, loss:2.107, acc:0.226
# step:695, loss:2.123, acc:0.236
# step:696, loss:2.184, acc:0.224
# step:697, loss:2.208, acc:0.246
# step:698, loss:2.156, acc:0.204
# step:699, loss:2.177, acc:0.226
# step:700, loss:2.116, acc:0.270
# step:701, loss:2.139, acc:0.254
# step:702, loss:2.122, acc:0.254
# step:703, loss:2.171, acc:0.222
# step:704, loss:2.156, acc:0.220
# step:705, loss:2.145, acc:0.232
# step:706, loss:2.182, acc:0.218
# step:707, loss:2.157, acc:0.238
# step:708, loss:2.191, acc:0.196
# step:709, loss:2.171, acc:0.202
# step:710, loss:2.197, acc:0.222
# step:711, loss:2.126, acc:0.256
# step:712, loss:2.136, acc:0.238
# step:713, loss:2.166, acc:0.224
# step:714, loss:2.208, acc:0.214
# step:715, loss:2.185, acc:0.220
# step:716, loss:2.190, acc:0.224
# step:717, loss:2.174, acc:0.234
# step:718, loss:2.207, acc:0.204
# step:719, loss:2.149, acc:0.226
# step:720, loss:2.171, acc:0.232
# step:721, loss:2.116, acc:0.238
# step:722, loss:2.135, acc:0.198
# step:723, loss:2.116, acc:0.224
# step:724, loss:2.119, acc:0.238
# step:725, loss:2.120, acc:0.240
# step:726, loss:2.135, acc:0.244
# step:727, loss:2.137, acc:0.216
# step:728, loss:2.124, acc:0.248
# step:729, loss:2.155, acc:0.244
# step:730, loss:2.131, acc:0.212
# step:731, loss:2.099, acc:0.238
# step:732, loss:2.135, acc:0.258
# step:733, loss:2.132, acc:0.254
# step:734, loss:2.177, acc:0.214
# step:735, loss:2.042, acc:0.256
# step:736, loss:2.094, acc:0.260
# step:737, loss:2.108, acc:0.234
# step:738, loss:2.142, acc:0.206
# step:739, loss:2.147, acc:0.238
# step:740, loss:2.123, acc:0.262
# step:741, loss:2.138, acc:0.230
# step:742, loss:2.185, acc:0.222
# step:743, loss:2.173, acc:0.250
# step:744, loss:2.125, acc:0.224
# step:745, loss:2.149, acc:0.242
# step:746, loss:2.155, acc:0.236
# step:747, loss:2.202, acc:0.214
# step:748, loss:2.114, acc:0.226
# step:749, loss:2.133, acc:0.250
# step:750, loss:2.237, acc:0.230
# step:751, loss:2.113, acc:0.204
# step:752, loss:2.123, acc:0.256
# step:753, loss:2.168, acc:0.242
# step:754, loss:2.133, acc:0.274
# step:755, loss:2.131, acc:0.216
# step:756, loss:2.120, acc:0.224
# step:757, loss:2.129, acc:0.250
# step:758, loss:2.126, acc:0.222
# step:759, loss:2.091, acc:0.256
# step:760, loss:2.109, acc:0.254
# step:761, loss:2.200, acc:0.198
# step:762, loss:2.081, acc:0.254
# step:763, loss:2.151, acc:0.210
# step:764, loss:2.109, acc:0.244
# step:765, loss:2.132, acc:0.228
# step:766, loss:2.165, acc:0.244
# step:767, loss:2.176, acc:0.204
# step:768, loss:2.115, acc:0.260
# step:769, loss:2.142, acc:0.232
# step:770, loss:2.182, acc:0.214
# step:771, loss:2.068, acc:0.260
# step:772, loss:2.101, acc:0.240
# step:773, loss:2.116, acc:0.242
# step:774, loss:2.171, acc:0.230
# step:775, loss:2.147, acc:0.216
# step:776, loss:2.119, acc:0.212
# step:777, loss:2.125, acc:0.220
# step:778, loss:2.133, acc:0.242
# step:779, loss:2.098, acc:0.250
# step:780, loss:2.133, acc:0.214
# step:781, loss:2.149, acc:0.214
# step:782, loss:2.112, acc:0.236
# step:783, loss:2.161, acc:0.208
# step:784, loss:2.144, acc:0.236
# step:785, loss:2.123, acc:0.198
# step:786, loss:2.145, acc:0.240
# step:787, loss:2.144, acc:0.228
# step:788, loss:2.173, acc:0.222
# step:789, loss:2.182, acc:0.228
# step:790, loss:2.121, acc:0.234
# step:791, loss:2.116, acc:0.238
# step:792, loss:2.173, acc:0.184
# step:793, loss:2.121, acc:0.230
# step:794, loss:2.078, acc:0.262
# step:795, loss:2.054, acc:0.240
# step:796, loss:2.148, acc:0.248
# step:797, loss:2.167, acc:0.244
# step:798, loss:2.122, acc:0.222
# step:799, loss:2.083, acc:0.238
# step:800, loss:2.143, acc:0.236
# step:801, loss:2.152, acc:0.238
# step:802, loss:2.090, acc:0.262
# step:803, loss:2.136, acc:0.254
# step:804, loss:2.102, acc:0.274
# step:805, loss:2.150, acc:0.226
# step:806, loss:2.128, acc:0.268
# step:807, loss:2.132, acc:0.200
# step:808, loss:2.166, acc:0.204
# step:809, loss:2.108, acc:0.228
# step:810, loss:2.085, acc:0.248
# step:811, loss:2.122, acc:0.242
# step:812, loss:2.133, acc:0.232
# step:813, loss:2.138, acc:0.232
# step:814, loss:2.078, acc:0.258
# step:815, loss:2.111, acc:0.260
# step:816, loss:2.124, acc:0.270
# step:817, loss:2.156, acc:0.226
# step:818, loss:2.147, acc:0.244
# step:819, loss:2.164, acc:0.252
# step:820, loss:2.117, acc:0.232
# step:821, loss:2.167, acc:0.240
# step:822, loss:2.104, acc:0.228
# step:823, loss:2.146, acc:0.254
# step:824, loss:2.084, acc:0.254
# step:825, loss:2.170, acc:0.224
# step:826, loss:2.123, acc:0.232
# step:827, loss:2.112, acc:0.262
# step:828, loss:2.095, acc:0.254
# step:829, loss:2.137, acc:0.220
# step:830, loss:2.097, acc:0.244
# step:831, loss:2.061, acc:0.262
# step:832, loss:2.118, acc:0.234
# step:833, loss:2.106, acc:0.240
# step:834, loss:2.164, acc:0.238
# step:835, loss:2.111, acc:0.242
# step:836, loss:2.136, acc:0.218
# step:837, loss:2.103, acc:0.222
# step:838, loss:2.109, acc:0.228
# step:839, loss:2.149, acc:0.242
# step:840, loss:2.132, acc:0.240
# step:841, loss:2.137, acc:0.230
# step:842, loss:2.140, acc:0.226
# step:843, loss:2.095, acc:0.246
# step:844, loss:2.155, acc:0.242
# step:845, loss:2.144, acc:0.216
# step:846, loss:2.101, acc:0.218
# step:847, loss:2.089, acc:0.236
# step:848, loss:2.080, acc:0.250
# step:849, loss:2.167, acc:0.230
# step:850, loss:2.161, acc:0.222
# step:851, loss:2.055, acc:0.244
# step:852, loss:2.133, acc:0.210
# step:853, loss:2.177, acc:0.212
# step:854, loss:2.085, acc:0.226
# step:855, loss:2.073, acc:0.266
# step:856, loss:2.102, acc:0.222
# step:857, loss:2.131, acc:0.252
# step:858, loss:2.122, acc:0.196
# step:859, loss:2.094, acc:0.218
# step:860, loss:2.162, acc:0.218
# step:861, loss:2.147, acc:0.228
# step:862, loss:2.117, acc:0.242
# step:863, loss:2.123, acc:0.212
# step:864, loss:2.105, acc:0.246
# step:865, loss:2.131, acc:0.240
# step:866, loss:2.106, acc:0.260
# step:867, loss:2.126, acc:0.268
# step:868, loss:2.075, acc:0.248
# step:869, loss:2.079, acc:0.268
# step:870, loss:2.009, acc:0.266
# step:871, loss:2.150, acc:0.248
# step:872, loss:2.205, acc:0.238
# step:873, loss:2.209, acc:0.230
# step:874, loss:2.147, acc:0.226
# step:875, loss:2.055, acc:0.232
# step:876, loss:2.113, acc:0.262
# step:877, loss:2.115, acc:0.226
# step:878, loss:2.161, acc:0.244
# step:879, loss:2.025, acc:0.274
# step:880, loss:2.191, acc:0.236
# step:881, loss:2.065, acc:0.272
# step:882, loss:2.084, acc:0.248
# step:883, loss:2.091, acc:0.244
# step:884, loss:2.105, acc:0.246
# step:885, loss:2.146, acc:0.230
# step:886, loss:2.062, acc:0.226
# step:887, loss:2.081, acc:0.252
# step:888, loss:2.094, acc:0.270
# step:889, loss:2.083, acc:0.226
# step:890, loss:2.172, acc:0.202
# step:891, loss:2.069, acc:0.292
# step:892, loss:2.171, acc:0.228
# step:893, loss:2.066, acc:0.226
# step:894, loss:2.079, acc:0.242
# step:895, loss:2.099, acc:0.260
# step:896, loss:2.123, acc:0.234
# step:897, loss:2.131, acc:0.254
# step:898, loss:2.137, acc:0.228
# step:899, loss:2.068, acc:0.280
# step:900, loss:2.078, acc:0.270
# step:901, loss:2.053, acc:0.228
# step:902, loss:2.105, acc:0.242
# step:903, loss:2.108, acc:0.210
# step:904, loss:2.112, acc:0.232
# step:905, loss:2.077, acc:0.244
# step:906, loss:2.034, acc:0.266
# step:907, loss:2.078, acc:0.260
# step:908, loss:2.064, acc:0.258
# step:909, loss:2.084, acc:0.258
# step:910, loss:2.052, acc:0.238
# step:911, loss:2.062, acc:0.264
# step:912, loss:2.044, acc:0.246
# step:913, loss:2.067, acc:0.240
# step:914, loss:2.111, acc:0.278
# step:915, loss:2.118, acc:0.236
# step:916, loss:2.081, acc:0.236
# step:917, loss:2.089, acc:0.256
# step:918, loss:2.063, acc:0.248
# step:919, loss:2.087, acc:0.258
# step:920, loss:2.116, acc:0.230
# step:921, loss:2.068, acc:0.254
# step:922, loss:2.078, acc:0.268
# step:923, loss:2.109, acc:0.242
# step:924, loss:2.064, acc:0.272
# step:925, loss:2.115, acc:0.270
# step:926, loss:2.115, acc:0.230
# step:927, loss:2.107, acc:0.238
# step:928, loss:2.096, acc:0.242
# step:929, loss:2.062, acc:0.268
# step:930, loss:2.076, acc:0.242
# step:931, loss:2.088, acc:0.226
# step:932, loss:2.110, acc:0.242
# step:933, loss:2.088, acc:0.250
# step:934, loss:2.105, acc:0.238
# step:935, loss:2.052, acc:0.262
# step:936, loss:2.101, acc:0.230
# step:937, loss:2.048, acc:0.242
# step:938, loss:2.034, acc:0.242
# step:939, loss:2.079, acc:0.276
# step:940, loss:2.079, acc:0.244
# step:941, loss:2.093, acc:0.236
# step:942, loss:2.109, acc:0.234
# step:943, loss:2.053, acc:0.228
# step:944, loss:2.123, acc:0.252
# step:945, loss:2.081, acc:0.234
# step:946, loss:2.056, acc:0.244
# step:947, loss:2.071, acc:0.288
# step:948, loss:2.073, acc:0.238
# step:949, loss:2.049, acc:0.246
# step:950, loss:2.100, acc:0.218
# step:951, loss:2.081, acc:0.230
# step:952, loss:2.069, acc:0.204
# step:953, loss:2.121, acc:0.236
# step:954, loss:1.976, acc:0.258
# step:955, loss:2.070, acc:0.250
# step:956, loss:2.069, acc:0.270
# step:957, loss:2.094, acc:0.260
# step:958, loss:2.114, acc:0.232
# step:959, loss:2.022, acc:0.258
# step:960, loss:2.156, acc:0.224
# step:961, loss:2.019, acc:0.268
# step:962, loss:2.084, acc:0.264
# step:963, loss:2.082, acc:0.260
# step:964, loss:2.080, acc:0.240
# step:965, loss:2.021, acc:0.262
# step:966, loss:2.021, acc:0.246
# step:967, loss:2.057, acc:0.232
# step:968, loss:2.043, acc:0.268
# step:969, loss:2.062, acc:0.256
# step:970, loss:2.125, acc:0.216
# step:971, loss:2.089, acc:0.266
# step:972, loss:2.103, acc:0.214
# step:973, loss:2.022, acc:0.244
# step:974, loss:2.093, acc:0.246
# step:975, loss:2.065, acc:0.230
# step:976, loss:2.074, acc:0.228
# step:977, loss:2.113, acc:0.264
# step:978, loss:2.112, acc:0.226
# step:979, loss:2.045, acc:0.266
# step:980, loss:2.110, acc:0.264
# step:981, loss:2.112, acc:0.246
# step:982, loss:2.134, acc:0.234
# step:983, loss:2.023, acc:0.248
# step:984, loss:2.026, acc:0.258
# step:985, loss:2.075, acc:0.222
# step:986, loss:2.060, acc:0.248
# step:987, loss:2.109, acc:0.244
# step:988, loss:2.090, acc:0.242
# step:989, loss:2.060, acc:0.262
# step:990, loss:2.075, acc:0.246
# step:991, loss:2.097, acc:0.294
# step:992, loss:2.038, acc:0.282
# step:993, loss:2.062, acc:0.254
# step:994, loss:2.051, acc:0.260
# step:995, loss:2.042, acc:0.240
# step:996, loss:2.161, acc:0.232
# step:997, loss:2.040, acc:0.242
# step:998, loss:2.113, acc:0.246
# step:999, loss:2.133, acc:0.232
# step:1000, loss:2.062, acc:0.260
# step:1001, loss:2.039, acc:0.270
# step:1002, loss:2.092, acc:0.250
# step:1003, loss:2.091, acc:0.234
# step:1004, loss:2.049, acc:0.280
# step:1005, loss:2.033, acc:0.258
# step:1006, loss:2.062, acc:0.256
# step:1007, loss:2.031, acc:0.240
# step:1008, loss:2.065, acc:0.268
# step:1009, loss:2.130, acc:0.224
# step:1010, loss:2.041, acc:0.268
# step:1011, loss:2.106, acc:0.228
# step:1012, loss:2.064, acc:0.234
# step:1013, loss:2.046, acc:0.234
# step:1014, loss:2.063, acc:0.244
# step:1015, loss:2.024, acc:0.270
# step:1016, loss:2.030, acc:0.254
# step:1017, loss:2.021, acc:0.268
# step:1018, loss:2.000, acc:0.268
# step:1019, loss:2.002, acc:0.260
# step:1020, loss:2.044, acc:0.240
# step:1021, loss:2.131, acc:0.208
# step:1022, loss:2.049, acc:0.260
# step:1023, loss:2.052, acc:0.244
# step:1024, loss:2.078, acc:0.274
# step:1025, loss:2.123, acc:0.242
# step:1026, loss:2.131, acc:0.220
# step:1027, loss:2.024, acc:0.244
# step:1028, loss:2.079, acc:0.250
# step:1029, loss:2.085, acc:0.242
# step:1030, loss:2.047, acc:0.252
# step:1031, loss:2.086, acc:0.222
# step:1032, loss:1.993, acc:0.272
# step:1033, loss:2.019, acc:0.272
# step:1034, loss:2.028, acc:0.248
# step:1035, loss:2.133, acc:0.240
# step:1036, loss:2.003, acc:0.258
# step:1037, loss:2.062, acc:0.240
# step:1038, loss:2.100, acc:0.250
# step:1039, loss:2.094, acc:0.262
# step:1040, loss:2.068, acc:0.228
# step:1041, loss:2.029, acc:0.248
# step:1042, loss:2.029, acc:0.300
# step:1043, loss:2.057, acc:0.258
# step:1044, loss:2.068, acc:0.268
# step:1045, loss:2.091, acc:0.226
# step:1046, loss:2.055, acc:0.250
# step:1047, loss:2.049, acc:0.250
# step:1048, loss:2.138, acc:0.206
# step:1049, loss:2.091, acc:0.246
# step:1050, loss:2.075, acc:0.250
# step:1051, loss:2.133, acc:0.262
# step:1052, loss:2.097, acc:0.240
# step:1053, loss:2.055, acc:0.252
# step:1054, loss:2.079, acc:0.276
# step:1055, loss:2.104, acc:0.230
# step:1056, loss:2.068, acc:0.272
# step:1057, loss:2.045, acc:0.256
# step:1058, loss:2.092, acc:0.216
# step:1059, loss:2.022, acc:0.266
# step:1060, loss:2.051, acc:0.232
# step:1061, loss:2.015, acc:0.262
# step:1062, loss:2.085, acc:0.248
# step:1063, loss:2.085, acc:0.234
# step:1064, loss:2.130, acc:0.200
# step:1065, loss:2.070, acc:0.218
# step:1066, loss:2.071, acc:0.256
# step:1067, loss:2.078, acc:0.242
# step:1068, loss:2.009, acc:0.270
# step:1069, loss:2.097, acc:0.226
# step:1070, loss:2.124, acc:0.232
# step:1071, loss:2.083, acc:0.250
# step:1072, loss:2.022, acc:0.254
# step:1073, loss:2.108, acc:0.230
# step:1074, loss:2.026, acc:0.228
# step:1075, loss:2.006, acc:0.292
# step:1076, loss:2.001, acc:0.256
# step:1077, loss:2.071, acc:0.226
# step:1078, loss:2.012, acc:0.272
# step:1079, loss:2.029, acc:0.248
# step:1080, loss:2.008, acc:0.258
# step:1081, loss:2.014, acc:0.288
# step:1082, loss:2.042, acc:0.236
# step:1083, loss:2.076, acc:0.238
# step:1084, loss:2.080, acc:0.240
# step:1085, loss:2.040, acc:0.282
# step:1086, loss:2.068, acc:0.264
# step:1087, loss:2.085, acc:0.244
# step:1088, loss:2.067, acc:0.218
# step:1089, loss:2.112, acc:0.250
# step:1090, loss:2.095, acc:0.218
# step:1091, loss:2.066, acc:0.240
# step:1092, loss:2.051, acc:0.260
# step:1093, loss:2.055, acc:0.248
# step:1094, loss:2.105, acc:0.234
# step:1095, loss:2.075, acc:0.262
# step:1096, loss:2.004, acc:0.284
# step:1097, loss:2.036, acc:0.266
# step:1098, loss:2.073, acc:0.262
# step:1099, loss:2.021, acc:0.264
# step:1100, loss:2.069, acc:0.216
# step:1101, loss:2.165, acc:0.184
# step:1102, loss:2.086, acc:0.212
# step:1103, loss:2.046, acc:0.272
# step:1104, loss:2.011, acc:0.258
# step:1105, loss:2.002, acc:0.266
# step:1106, loss:2.049, acc:0.244
# step:1107, loss:2.065, acc:0.246
# step:1108, loss:1.975, acc:0.270
# step:1109, loss:1.990, acc:0.264
# step:1110, loss:2.003, acc:0.290
# step:1111, loss:2.051, acc:0.260
# step:1112, loss:2.107, acc:0.250
# step:1113, loss:2.060, acc:0.252
# step:1114, loss:2.028, acc:0.232
# step:1115, loss:2.049, acc:0.240
# step:1116, loss:2.082, acc:0.272
# step:1117, loss:2.060, acc:0.240
# step:1118, loss:2.079, acc:0.266
# step:1119, loss:2.055, acc:0.250
# step:1120, loss:2.050, acc:0.240
# step:1121, loss:2.067, acc:0.250
# step:1122, loss:2.009, acc:0.270
# step:1123, loss:2.022, acc:0.236
# step:1124, loss:2.057, acc:0.270
# step:1125, loss:2.028, acc:0.272
# step:1126, loss:2.064, acc:0.252
# step:1127, loss:2.066, acc:0.238
# step:1128, loss:2.005, acc:0.258
# step:1129, loss:2.052, acc:0.282
# step:1130, loss:1.989, acc:0.272
# step:1131, loss:2.063, acc:0.230
# step:1132, loss:2.026, acc:0.258
# step:1133, loss:2.028, acc:0.230
# step:1134, loss:1.969, acc:0.276
# step:1135, loss:1.956, acc:0.314
# step:1136, loss:1.971, acc:0.268
# step:1137, loss:2.001, acc:0.274
# step:1138, loss:2.096, acc:0.218
# step:1139, loss:2.070, acc:0.240
# step:1140, loss:2.005, acc:0.270
# step:1141, loss:2.063, acc:0.234
# step:1142, loss:2.124, acc:0.254
# step:1143, loss:2.060, acc:0.232
# step:1144, loss:2.083, acc:0.218
# step:1145, loss:2.035, acc:0.266
# step:1146, loss:2.051, acc:0.266
# step:1147, loss:2.031, acc:0.254
# step:1148, loss:2.030, acc:0.238
# step:1149, loss:2.013, acc:0.246
# step:1150, loss:2.036, acc:0.218
# step:1151, loss:2.030, acc:0.240
# step:1152, loss:2.009, acc:0.288
# step:1153, loss:2.029, acc:0.236
# step:1154, loss:2.018, acc:0.230
# step:1155, loss:2.007, acc:0.270
# step:1156, loss:2.006, acc:0.244
# step:1157, loss:2.077, acc:0.248
# step:1158, loss:2.096, acc:0.244
# step:1159, loss:2.108, acc:0.268
# step:1160, loss:2.023, acc:0.264
# step:1161, loss:2.102, acc:0.242
# step:1162, loss:2.075, acc:0.244
# step:1163, loss:2.048, acc:0.254
# step:1164, loss:2.016, acc:0.254
# step:1165, loss:1.992, acc:0.276
# step:1166, loss:2.026, acc:0.282
# step:1167, loss:1.951, acc:0.266
# step:1168, loss:2.124, acc:0.240
# step:1169, loss:2.068, acc:0.220
# step:1170, loss:2.021, acc:0.246
# step:1171, loss:2.009, acc:0.276
# step:1172, loss:2.033, acc:0.254
# step:1173, loss:2.021, acc:0.250
# step:1174, loss:2.059, acc:0.214
# step:1175, loss:1.959, acc:0.252
# step:1176, loss:2.145, acc:0.228
# step:1177, loss:2.110, acc:0.268
# step:1178, loss:1.988, acc:0.234
# step:1179, loss:2.010, acc:0.268
# step:1180, loss:2.014, acc:0.268
# step:1181, loss:2.067, acc:0.252
# step:1182, loss:2.018, acc:0.274
# step:1183, loss:2.029, acc:0.264
# step:1184, loss:2.070, acc:0.248
# step:1185, loss:1.954, acc:0.264
# step:1186, loss:2.026, acc:0.256
# step:1187, loss:2.061, acc:0.264
# step:1188, loss:2.024, acc:0.252
# step:1189, loss:2.019, acc:0.236
# step:1190, loss:2.055, acc:0.230
# step:1191, loss:2.099, acc:0.214
# step:1192, loss:2.032, acc:0.252
# step:1193, loss:2.026, acc:0.256
# step:1194, loss:2.032, acc:0.238
# step:1195, loss:2.038, acc:0.266
# step:1196, loss:2.053, acc:0.242
# step:1197, loss:2.030, acc:0.256
# step:1198, loss:2.035, acc:0.272
# step:1199, loss:2.062, acc:0.222
# step:1200, loss:1.988, acc:0.256
# step:1201, loss:2.048, acc:0.254
# step:1202, loss:2.031, acc:0.256
# step:1203, loss:1.924, acc:0.292
# step:1204, loss:2.052, acc:0.250
# step:1205, loss:2.073, acc:0.264
# step:1206, loss:2.038, acc:0.270
# step:1207, loss:2.084, acc:0.274
# step:1208, loss:2.016, acc:0.300
# step:1209, loss:2.017, acc:0.252
# step:1210, loss:2.134, acc:0.242
# step:1211, loss:1.996, acc:0.278
# step:1212, loss:2.038, acc:0.284
# step:1213, loss:1.957, acc:0.310
# step:1214, loss:2.024, acc:0.224
# step:1215, loss:2.020, acc:0.266
# step:1216, loss:2.124, acc:0.268
# step:1217, loss:2.024, acc:0.280
# step:1218, loss:1.987, acc:0.254
# step:1219, loss:2.015, acc:0.274
# step:1220, loss:2.062, acc:0.250
# step:1221, loss:2.022, acc:0.250
# step:1222, loss:2.081, acc:0.246
# step:1223, loss:2.050, acc:0.254
# step:1224, loss:2.018, acc:0.222
# step:1225, loss:2.015, acc:0.242
# step:1226, loss:1.991, acc:0.262
# step:1227, loss:2.042, acc:0.244
# step:1228, loss:2.066, acc:0.222
# step:1229, loss:1.952, acc:0.280
# step:1230, loss:2.038, acc:0.266
# step:1231, loss:2.049, acc:0.250
# step:1232, loss:1.953, acc:0.278
# step:1233, loss:1.934, acc:0.302
# step:1234, loss:2.017, acc:0.276
# step:1235, loss:2.014, acc:0.264
# step:1236, loss:2.058, acc:0.272
# step:1237, loss:2.011, acc:0.264
# step:1238, loss:2.033, acc:0.236
# step:1239, loss:2.062, acc:0.250
# step:1240, loss:1.972, acc:0.310
# step:1241, loss:2.001, acc:0.274
# step:1242, loss:1.968, acc:0.260
# step:1243, loss:2.006, acc:0.274
# step:1244, loss:2.031, acc:0.254
# step:1245, loss:2.008, acc:0.294
# step:1246, loss:1.976, acc:0.280
# step:1247, loss:2.019, acc:0.244
# step:1248, loss:2.018, acc:0.282
# step:1249, loss:2.044, acc:0.284
# step:1250, loss:2.017, acc:0.272
# step:1251, loss:2.088, acc:0.224
# step:1252, loss:1.948, acc:0.288
# step:1253, loss:2.081, acc:0.250
# step:1254, loss:1.985, acc:0.250
# step:1255, loss:2.065, acc:0.268
# step:1256, loss:2.026, acc:0.254
# step:1257, loss:2.016, acc:0.248
# step:1258, loss:1.987, acc:0.242
# step:1259, loss:1.980, acc:0.262
# step:1260, loss:1.959, acc:0.290
# step:1261, loss:2.012, acc:0.230
# step:1262, loss:1.973, acc:0.282
# step:1263, loss:2.112, acc:0.254
# step:1264, loss:1.997, acc:0.296
# step:1265, loss:1.998, acc:0.248
# step:1266, loss:1.893, acc:0.310
# step:1267, loss:1.969, acc:0.254
# step:1268, loss:2.056, acc:0.262
# step:1269, loss:1.883, acc:0.314
# step:1270, loss:2.013, acc:0.262
# step:1271, loss:2.016, acc:0.240
# step:1272, loss:2.159, acc:0.258
# step:1273, loss:2.065, acc:0.258
# step:1274, loss:2.040, acc:0.278
# step:1275, loss:2.078, acc:0.260
# step:1276, loss:2.056, acc:0.294
# step:1277, loss:2.100, acc:0.222
# step:1278, loss:1.956, acc:0.268
# step:1279, loss:1.967, acc:0.264
# step:1280, loss:2.037, acc:0.282
# step:1281, loss:2.083, acc:0.230
# step:1282, loss:2.014, acc:0.256
# step:1283, loss:2.017, acc:0.272
# step:1284, loss:1.999, acc:0.270
# step:1285, loss:1.973, acc:0.278
# step:1286, loss:2.080, acc:0.240
# step:1287, loss:1.953, acc:0.270
# step:1288, loss:2.023, acc:0.260
# step:1289, loss:2.014, acc:0.294
# step:1290, loss:1.970, acc:0.288
# step:1291, loss:2.009, acc:0.246
# step:1292, loss:2.021, acc:0.242
# step:1293, loss:2.003, acc:0.262
# step:1294, loss:2.014, acc:0.236
# step:1295, loss:2.025, acc:0.236
# step:1296, loss:2.075, acc:0.254
# step:1297, loss:1.948, acc:0.270
# step:1298, loss:1.966, acc:0.256
# step:1299, loss:1.995, acc:0.276
# step:1300, loss:2.009, acc:0.272
# step:1301, loss:2.041, acc:0.270
# step:1302, loss:2.064, acc:0.236
# step:1303, loss:2.048, acc:0.288
# step:1304, loss:2.014, acc:0.260
# step:1305, loss:2.027, acc:0.268
# step:1306, loss:1.962, acc:0.288
# step:1307, loss:2.007, acc:0.270
# step:1308, loss:1.960, acc:0.296
# step:1309, loss:1.953, acc:0.258
# step:1310, loss:2.011, acc:0.236
# step:1311, loss:2.056, acc:0.270
# step:1312, loss:1.987, acc:0.270
# step:1313, loss:1.985, acc:0.286
# step:1314, loss:2.112, acc:0.234
# step:1315, loss:1.958, acc:0.294
# step:1316, loss:1.978, acc:0.244
# step:1317, loss:2.050, acc:0.226
# step:1318, loss:2.015, acc:0.264
# step:1319, loss:1.960, acc:0.288
# step:1320, loss:2.065, acc:0.232
# step:1321, loss:2.068, acc:0.226
# step:1322, loss:2.037, acc:0.302
# step:1323, loss:2.026, acc:0.250
# step:1324, loss:1.994, acc:0.258
# step:1325, loss:1.988, acc:0.276
# step:1326, loss:2.006, acc:0.266
# step:1327, loss:2.032, acc:0.232
# step:1328, loss:2.012, acc:0.234
# step:1329, loss:2.011, acc:0.266
# step:1330, loss:1.990, acc:0.272
# step:1331, loss:1.963, acc:0.266
# step:1332, loss:1.980, acc:0.300
# step:1333, loss:2.100, acc:0.246
# step:1334, loss:1.948, acc:0.284
# step:1335, loss:2.023, acc:0.258
# step:1336, loss:2.053, acc:0.262
# step:1337, loss:1.962, acc:0.268
# step:1338, loss:1.985, acc:0.262
# step:1339, loss:2.084, acc:0.230
# step:1340, loss:1.963, acc:0.272
# step:1341, loss:2.046, acc:0.248
# step:1342, loss:1.952, acc:0.282
# step:1343, loss:1.957, acc:0.290
# step:1344, loss:2.037, acc:0.256
# step:1345, loss:1.959, acc:0.308
# step:1346, loss:2.012, acc:0.274
# step:1347, loss:2.051, acc:0.264
# step:1348, loss:2.035, acc:0.260
# step:1349, loss:2.101, acc:0.258
# step:1350, loss:1.977, acc:0.296
# step:1351, loss:1.936, acc:0.308
# step:1352, loss:1.979, acc:0.304
# step:1353, loss:1.982, acc:0.266
# step:1354, loss:1.984, acc:0.268
# step:1355, loss:2.033, acc:0.246
# step:1356, loss:1.947, acc:0.256
# step:1357, loss:1.980, acc:0.282
# step:1358, loss:2.057, acc:0.228
# step:1359, loss:1.952, acc:0.298
# step:1360, loss:2.020, acc:0.252
# step:1361, loss:1.972, acc:0.260
# step:1362, loss:1.966, acc:0.276
# step:1363, loss:1.928, acc:0.306
# step:1364, loss:1.950, acc:0.296
# step:1365, loss:2.003, acc:0.276
# step:1366, loss:1.957, acc:0.272
# step:1367, loss:1.975, acc:0.264
# step:1368, loss:2.013, acc:0.268
# step:1369, loss:2.023, acc:0.264
# step:1370, loss:1.919, acc:0.290
# step:1371, loss:2.035, acc:0.286
# step:1372, loss:1.995, acc:0.264
# step:1373, loss:1.982, acc:0.300
# step:1374, loss:1.943, acc:0.282
# step:1375, loss:1.967, acc:0.262
# step:1376, loss:1.994, acc:0.292
# step:1377, loss:2.034, acc:0.288
# step:1378, loss:1.980, acc:0.298
# step:1379, loss:1.963, acc:0.272
# step:1380, loss:2.002, acc:0.290
# step:1381, loss:1.942, acc:0.294
# step:1382, loss:1.913, acc:0.318
# step:1383, loss:1.975, acc:0.264
# step:1384, loss:1.995, acc:0.268
# step:1385, loss:1.967, acc:0.256
# step:1386, loss:1.978, acc:0.268
# step:1387, loss:1.978, acc:0.300
# step:1388, loss:1.902, acc:0.308
# step:1389, loss:2.002, acc:0.276
# step:1390, loss:1.972, acc:0.278
# step:1391, loss:2.007, acc:0.280
# step:1392, loss:1.955, acc:0.306
# step:1393, loss:1.981, acc:0.292
# step:1394, loss:1.953, acc:0.274
# step:1395, loss:1.883, acc:0.290
# step:1396, loss:1.975, acc:0.270
# step:1397, loss:1.956, acc:0.282
# step:1398, loss:2.023, acc:0.278
# step:1399, loss:1.941, acc:0.294
# step:1400, loss:1.975, acc:0.270
# step:1401, loss:1.928, acc:0.294
# step:1402, loss:2.038, acc:0.302
# step:1403, loss:1.971, acc:0.276
# step:1404, loss:1.945, acc:0.288
# step:1405, loss:1.974, acc:0.284
# step:1406, loss:1.906, acc:0.312
# step:1407, loss:1.937, acc:0.336
# step:1408, loss:1.950, acc:0.300
# step:1409, loss:1.956, acc:0.288
# step:1410, loss:1.930, acc:0.300
# step:1411, loss:1.935, acc:0.274
# step:1412, loss:1.982, acc:0.264
# step:1413, loss:2.026, acc:0.262
# step:1414, loss:1.936, acc:0.294
# step:1415, loss:1.972, acc:0.286
# step:1416, loss:1.973, acc:0.232
# step:1417, loss:2.041, acc:0.248
# step:1418, loss:1.947, acc:0.320
# step:1419, loss:2.051, acc:0.286
# step:1420, loss:1.927, acc:0.282
# step:1421, loss:1.907, acc:0.302
# step:1422, loss:1.997, acc:0.304
# step:1423, loss:1.976, acc:0.286
# step:1424, loss:2.021, acc:0.272
# step:1425, loss:1.946, acc:0.268
# step:1426, loss:2.037, acc:0.262
# step:1427, loss:2.007, acc:0.262
# step:1428, loss:1.970, acc:0.242
# step:1429, loss:1.970, acc:0.234
# step:1430, loss:1.931, acc:0.300
# step:1431, loss:1.955, acc:0.260
# step:1432, loss:1.956, acc:0.260
# step:1433, loss:1.978, acc:0.288
# step:1434, loss:1.937, acc:0.272
# step:1435, loss:1.927, acc:0.298
# step:1436, loss:1.962, acc:0.260
# step:1437, loss:1.904, acc:0.278
# step:1438, loss:1.879, acc:0.296
# step:1439, loss:2.004, acc:0.280
# step:1440, loss:1.966, acc:0.276
# step:1441, loss:1.963, acc:0.272
# step:1442, loss:1.990, acc:0.288
# step:1443, loss:1.945, acc:0.316
# step:1444, loss:1.903, acc:0.312
# step:1445, loss:1.900, acc:0.292
# step:1446, loss:1.954, acc:0.290
# step:1447, loss:1.937, acc:0.334
# step:1448, loss:1.975, acc:0.294
# step:1449, loss:2.003, acc:0.278
# step:1450, loss:1.934, acc:0.300
# step:1451, loss:2.001, acc:0.276
# step:1452, loss:1.967, acc:0.282
# step:1453, loss:1.994, acc:0.266
# step:1454, loss:1.945, acc:0.326
# step:1455, loss:1.932, acc:0.276
# step:1456, loss:1.946, acc:0.272
# step:1457, loss:1.878, acc:0.322
# step:1458, loss:1.889, acc:0.298
# step:1459, loss:1.969, acc:0.334
# step:1460, loss:1.953, acc:0.320
# step:1461, loss:1.998, acc:0.298
# step:1462, loss:1.933, acc:0.310
# step:1463, loss:1.983, acc:0.290
# step:1464, loss:1.947, acc:0.298
# step:1465, loss:1.952, acc:0.274
# step:1466, loss:1.940, acc:0.260
# step:1467, loss:1.962, acc:0.292
# step:1468, loss:1.937, acc:0.282
# step:1469, loss:1.903, acc:0.328
# step:1470, loss:1.930, acc:0.280
# step:1471, loss:1.910, acc:0.316
# step:1472, loss:1.881, acc:0.332
# step:1473, loss:1.889, acc:0.314
# step:1474, loss:1.991, acc:0.260
# step:1475, loss:1.997, acc:0.270
# step:1476, loss:1.892, acc:0.292
# step:1477, loss:1.894, acc:0.282
# step:1478, loss:1.886, acc:0.308
# step:1479, loss:1.979, acc:0.306
# step:1480, loss:1.949, acc:0.270
# step:1481, loss:1.939, acc:0.282
# step:1482, loss:1.944, acc:0.308
# step:1483, loss:1.929, acc:0.280
# step:1484, loss:1.954, acc:0.274
# step:1485, loss:1.854, acc:0.330
# ...
# step:1516, loss:1.964, acc:0.292
# step:1517, loss:1.929, acc:0.298
# step:1518, loss:1.963, acc:0.270
# step:1519, loss:1.940, acc:0.296
# step:1520, loss:1.891, acc:0.308
# step:1521, loss:1.923, acc:0.324
# step:1522, loss:1.918, acc:0.304
# step:1523, loss:1.941, acc:0.288
# step:1524, loss:1.927, acc:0.304
# step:1525, loss:1.907, acc:0.300
# step:1526, loss:1.981, acc:0.276
# step:1527, loss:1.875, acc:0.308
# step:1528, loss:1.936, acc:0.316
# step:1529, loss:1.924, acc:0.316
# step:1530, loss:1.984, acc:0.316
# step:1531, loss:1.913, acc:0.326
# step:1532, loss:1.925, acc:0.312
# step:1533, loss:1.943, acc:0.276
# step:1534, loss:1.901, acc:0.308
# step:1535, loss:2.001, acc:0.242
# step:1536, loss:1.916, acc:0.286
# step:1537, loss:1.889, acc:0.320
# step:1538, loss:1.894, acc:0.326
# step:1539, loss:1.845, acc:0.344
# step:1540, loss:1.948, acc:0.294
# step:1541, loss:1.891, acc:0.312
# step:1542, loss:1.962, acc:0.298
# step:1543, loss:1.864, acc:0.334
# step:1544, loss:1.900, acc:0.328
# step:1545, loss:1.944, acc:0.294
# step:1546, loss:1.934, acc:0.280
# step:1547, loss:1.956, acc:0.280
# step:1548, loss:1.860, acc:0.344
# step:1549, loss:1.860, acc:0.312
# step:1550, loss:1.883, acc:0.302
# step:1551, loss:1.921, acc:0.282
# step:1552, loss:1.935, acc:0.326
# step:1553, loss:1.913, acc:0.292
# step:1554, loss:1.870, acc:0.338
# step:1555, loss:1.952, acc:0.298
# step:1556, loss:1.962, acc:0.286
# step:1557, loss:1.965, acc:0.294
# step:1558, loss:1.843, acc:0.324
# step:1559, loss:1.875, acc:0.328
# step:1560, loss:1.914, acc:0.320
# step:1561, loss:1.941, acc:0.268
# step:1562, loss:1.869, acc:0.302
# step:1563, loss:1.870, acc:0.326
# step:1564, loss:1.955, acc:0.304
# step:1565, loss:1.905, acc:0.310
# step:1566, loss:1.847, acc:0.376
# step:1567, loss:1.922, acc:0.310
# step:1568, loss:1.949, acc:0.296
# step:1569, loss:1.810, acc:0.320
# step:1570, loss:1.949, acc:0.288
# step:1571, loss:1.955, acc:0.322
# step:1572, loss:1.981, acc:0.266
# step:1573, loss:1.967, acc:0.306
# step:1574, loss:1.942, acc:0.298
# step:1575, loss:1.910, acc:0.298
# step:1576, loss:1.936, acc:0.284
# step:1577, loss:1.854, acc:0.304
# step:1578, loss:1.871, acc:0.270
# step:1579, loss:1.925, acc:0.286
# step:1580, loss:1.903, acc:0.290
# step:1581, loss:1.991, acc:0.276
# step:1582, loss:1.958, acc:0.302
# step:1583, loss:1.862, acc:0.334
# step:1584, loss:1.911, acc:0.332
# step:1585, loss:1.870, acc:0.316
# step:1586, loss:2.001, acc:0.294
# step:1587, loss:1.961, acc:0.290
# step:1588, loss:1.878, acc:0.352
# step:1589, loss:1.908, acc:0.324
# step:1590, loss:1.976, acc:0.250
# step:1591, loss:1.912, acc:0.314
# step:1592, loss:1.905, acc:0.304
# step:1593, loss:1.937, acc:0.300
# step:1594, loss:1.940, acc:0.296
# step:1595, loss:1.982, acc:0.298
# step:1596, loss:1.929, acc:0.262
# step:1597, loss:1.913, acc:0.320
# step:1598, loss:1.951, acc:0.282
# step:1599, loss:1.936, acc:0.310
# step:1600, loss:1.977, acc:0.292
# step:1601, loss:1.869, acc:0.308
# step:1602, loss:1.959, acc:0.292
# step:1603, loss:1.866, acc:0.340
# step:1604, loss:1.885, acc:0.330
# step:1605, loss:1.926, acc:0.322
# step:1606, loss:2.066, acc:0.282
# step:1607, loss:1.894, acc:0.302
# step:1608, loss:1.899, acc:0.340
# step:1609, loss:1.894, acc:0.320
# step:1610, loss:1.861, acc:0.346
# step:1611, loss:1.989, acc:0.300
# step:1612, loss:1.904, acc:0.306
# step:1613, loss:1.830, acc:0.312
# step:1614, loss:1.834, acc:0.346
# step:1615, loss:2.076, acc:0.270
# step:1616, loss:1.894, acc:0.326
# step:1617, loss:1.830, acc:0.322
# step:1618, loss:1.966, acc:0.290
# step:1619, loss:1.886, acc:0.330
# step:1620, loss:1.857, acc:0.318
# step:1621, loss:1.884, acc:0.336
# step:1622, loss:1.914, acc:0.280
# step:1623, loss:1.838, acc:0.326
# step:1624, loss:1.896, acc:0.284
# step:1625, loss:1.856, acc:0.320
# step:1626, loss:1.846, acc:0.330
# step:1627, loss:1.871, acc:0.318
# step:1628, loss:1.933, acc:0.302
# step:1629, loss:1.893, acc:0.312
# step:1630, loss:1.857, acc:0.338
# step:1631, loss:1.876, acc:0.312
# step:1632, loss:1.876, acc:0.316
# step:1633, loss:1.881, acc:0.320
# step:1634, loss:1.902, acc:0.316
# step:1635, loss:1.945, acc:0.324
# step:1636, loss:1.887, acc:0.302
# step:1637, loss:1.945, acc:0.288
# step:1638, loss:1.912, acc:0.314
# step:1639, loss:1.996, acc:0.290
# step:1640, loss:1.866, acc:0.308
# step:1641, loss:1.922, acc:0.284
# step:1642, loss:1.917, acc:0.286
# step:1643, loss:1.939, acc:0.282
# step:1644, loss:1.957, acc:0.286
# step:1645, loss:1.927, acc:0.314
# step:1646, loss:1.898, acc:0.312
# step:1647, loss:1.941, acc:0.316
# step:1648, loss:1.867, acc:0.338
# step:1649, loss:1.957, acc:0.270
# step:1650, loss:1.836, acc:0.318
# step:1651, loss:1.931, acc:0.304
# step:1652, loss:1.889, acc:0.328
# step:1653, loss:1.872, acc:0.292
# step:1654, loss:1.919, acc:0.318
# step:1655, loss:1.788, acc:0.356
# step:1656, loss:1.876, acc:0.324
# step:1657, loss:1.988, acc:0.284
# step:1658, loss:1.895, acc:0.326
# step:1659, loss:1.883, acc:0.356
# step:1660, loss:1.754, acc:0.360
# step:1661, loss:1.958, acc:0.290
# step:1662, loss:1.893, acc:0.308
# step:1663, loss:1.970, acc:0.308
# step:1664, loss:1.890, acc:0.330
# step:1665, loss:1.905, acc:0.318
# step:1666, loss:1.886, acc:0.312
# step:1667, loss:1.848, acc:0.316
# step:1668, loss:1.770, acc:0.360
# step:1669, loss:1.810, acc:0.326
# step:1670, loss:1.901, acc:0.316
# step:1671, loss:1.861, acc:0.326
# step:1672, loss:1.895, acc:0.302
# step:1673, loss:1.865, acc:0.332
# step:1674, loss:1.891, acc:0.344
# step:1675, loss:1.869, acc:0.318
# step:1676, loss:1.891, acc:0.346
# step:1677, loss:1.871, acc:0.310
# step:1678, loss:1.851, acc:0.344
# step:1679, loss:1.774, acc:0.348
# step:1680, loss:1.872, acc:0.336
# step:1681, loss:1.782, acc:0.368
# step:1682, loss:1.984, acc:0.296
# step:1683, loss:1.873, acc:0.334
# step:1684, loss:1.859, acc:0.296
# step:1685, loss:1.910, acc:0.304
# step:1686, loss:1.898, acc:0.336
# step:1687, loss:1.918, acc:0.302
# step:1688, loss:1.844, acc:0.322
# step:1689, loss:1.828, acc:0.324
# step:1690, loss:1.822, acc:0.348
# step:1691, loss:1.893, acc:0.316
# step:1692, loss:1.868, acc:0.302
# step:1693, loss:1.873, acc:0.316
# step:1694, loss:1.875, acc:0.332
# step:1695, loss:1.910, acc:0.280
# step:1696, loss:1.876, acc:0.320
# step:1697, loss:1.911, acc:0.298
# step:1698, loss:1.809, acc:0.338
# step:1699, loss:1.879, acc:0.328
# step:1700, loss:1.894, acc:0.302
# step:1701, loss:1.830, acc:0.314
# step:1702, loss:1.941, acc:0.292
# step:1703, loss:1.959, acc:0.308
# step:1704, loss:1.800, acc:0.318
# step:1705, loss:1.867, acc:0.316
# step:1706, loss:1.753, acc:0.336
# step:1707, loss:1.847, acc:0.302
# step:1708, loss:1.871, acc:0.332
# step:1709, loss:1.893, acc:0.344
# step:1710, loss:1.823, acc:0.340
# step:1711, loss:1.898, acc:0.292
# step:1712, loss:1.931, acc:0.312
# step:1713, loss:1.816, acc:0.336
# step:1714, loss:1.824, acc:0.344
# step:1715, loss:1.812, acc:0.324
# step:1716, loss:1.854, acc:0.328
# step:1717, loss:1.870, acc:0.310
# step:1718, loss:1.922, acc:0.306
# step:1719, loss:1.896, acc:0.318
# step:1720, loss:1.822, acc:0.314
# step:1721, loss:1.865, acc:0.330
# step:1722, loss:1.868, acc:0.324
# step:1723, loss:1.916, acc:0.282
# step:1724, loss:1.868, acc:0.338
# step:1725, loss:1.859, acc:0.312
# step:1726, loss:1.819, acc:0.320
# step:1727, loss:1.890, acc:0.318
# step:1728, loss:1.866, acc:0.278
# step:1729, loss:1.828, acc:0.348
# step:1730, loss:1.879, acc:0.312
# step:1731, loss:1.935, acc:0.312
# step:1732, loss:1.863, acc:0.292
# step:1733, loss:1.941, acc:0.314
# step:1734, loss:1.884, acc:0.346
# step:1735, loss:1.888, acc:0.320
# step:1736, loss:1.919, acc:0.292
# step:1737, loss:1.796, acc:0.340
# step:1738, loss:1.925, acc:0.296
# step:1739, loss:1.916, acc:0.312
# step:1740, loss:1.950, acc:0.304
# step:1741, loss:1.977, acc:0.268
# step:1742, loss:1.911, acc:0.310
# step:1743, loss:1.874, acc:0.294
# step:1744, loss:1.893, acc:0.324
# step:1745, loss:1.912, acc:0.300
# step:1746, loss:1.925, acc:0.288
# step:1747, loss:1.868, acc:0.328
# step:1748, loss:1.864, acc:0.306
# step:1749, loss:1.902, acc:0.350
# step:1750, loss:1.802, acc:0.346
# step:1751, loss:1.847, acc:0.342
# step:1752, loss:1.887, acc:0.330
# step:1753, loss:1.858, acc:0.338
# step:1754, loss:1.879, acc:0.304
# step:1755, loss:1.864, acc:0.348
# step:1756, loss:1.972, acc:0.310
# step:1757, loss:1.954, acc:0.296
# step:1758, loss:1.833, acc:0.322
# step:1759, loss:1.846, acc:0.340
# step:1760, loss:1.821, acc:0.328
# step:1761, loss:1.884, acc:0.344
# step:1762, loss:1.860, acc:0.312
# step:1763, loss:1.790, acc:0.328
# step:1764, loss:1.896, acc:0.302
# step:1765, loss:1.924, acc:0.318
# step:1766, loss:1.886, acc:0.322
# step:1767, loss:1.799, acc:0.338
# step:1768, loss:1.806, acc:0.378
# step:1769, loss:1.809, acc:0.326
# step:1770, loss:1.799, acc:0.328
# step:1771, loss:1.904, acc:0.322
# step:1772, loss:1.885, acc:0.340
# step:1773, loss:1.845, acc:0.346
# step:1774, loss:1.846, acc:0.308
# step:1775, loss:1.840, acc:0.322
# step:1776, loss:1.829, acc:0.342
# step:1777, loss:1.880, acc:0.320
# step:1778, loss:1.832, acc:0.334
# step:1779, loss:1.878, acc:0.324
# step:1780, loss:1.819, acc:0.354
# step:1781, loss:1.936, acc:0.308
# step:1782, loss:1.843, acc:0.324
# step:1783, loss:1.828, acc:0.324
# step:1784, loss:1.898, acc:0.298
# step:1785, loss:1.762, acc:0.354
# step:1786, loss:1.840, acc:0.312
# step:1787, loss:1.939, acc:0.318
# step:1788, loss:1.895, acc:0.272
# step:1789, loss:1.915, acc:0.302
# step:1790, loss:1.882, acc:0.316
# step:1791, loss:1.826, acc:0.316
# step:1792, loss:1.802, acc:0.326
# step:1793, loss:1.812, acc:0.350
# step:1794, loss:1.832, acc:0.362
# step:1795, loss:1.781, acc:0.330
# step:1796, loss:1.753, acc:0.346
# step:1797, loss:1.814, acc:0.352
# step:1798, loss:1.904, acc:0.306
# step:1799, loss:1.788, acc:0.360
# step:1800, loss:1.795, acc:0.332
# step:1801, loss:1.833, acc:0.320
# step:1802, loss:1.898, acc:0.310
# step:1803, loss:1.835, acc:0.336
# step:1804, loss:1.866, acc:0.336
# step:1805, loss:1.843, acc:0.308
# step:1806, loss:1.894, acc:0.320
# step:1807, loss:1.789, acc:0.322
# step:1808, loss:1.844, acc:0.340
# step:1809, loss:1.826, acc:0.332
# step:1810, loss:1.736, acc:0.396
# step:1811, loss:1.872, acc:0.304
# step:1812, loss:1.837, acc:0.326
# step:1813, loss:1.859, acc:0.352
# step:1814, loss:1.903, acc:0.308
# step:1815, loss:1.770, acc:0.330
# step:1816, loss:1.784, acc:0.334
# step:1817, loss:1.823, acc:0.332
# step:1818, loss:1.736, acc:0.352
# step:1819, loss:1.772, acc:0.348
# step:1820, loss:1.787, acc:0.336
# step:1821, loss:1.871, acc:0.314
# step:1822, loss:1.787, acc:0.368
# step:1823, loss:1.841, acc:0.314
# step:1824, loss:1.848, acc:0.342
# step:1825, loss:1.882, acc:0.318
# step:1826, loss:1.883, acc:0.336
# step:1827, loss:1.790, acc:0.350
# step:1828, loss:1.967, acc:0.322
# step:1829, loss:1.841, acc:0.346
# step:1830, loss:1.838, acc:0.346
# step:1831, loss:1.866, acc:0.316
# step:1832, loss:2.001, acc:0.326
# step:1833, loss:1.816, acc:0.348
# step:1834, loss:1.927, acc:0.292
# step:1835, loss:1.776, acc:0.342
# step:1836, loss:1.896, acc:0.284
# step:1837, loss:1.845, acc:0.306
# step:1838, loss:2.005, acc:0.270
# step:1839, loss:1.833, acc:0.328
# step:1840, loss:1.841, acc:0.316
# step:1841, loss:1.892, acc:0.306
# step:1842, loss:1.853, acc:0.372
# step:1843, loss:1.871, acc:0.340
# step:1844, loss:1.838, acc:0.336
# step:1845, loss:1.842, acc:0.312
# step:1846, loss:1.806, acc:0.322
# step:1847, loss:1.826, acc:0.360
# step:1848, loss:1.848, acc:0.338
# step:1849, loss:1.834, acc:0.342
# step:1850, loss:1.841, acc:0.332
# step:1851, loss:1.801, acc:0.332
# step:1852, loss:1.881, acc:0.306
# step:1853, loss:1.740, acc:0.384
# step:1854, loss:1.844, acc:0.340
# step:1855, loss:1.804, acc:0.340
# step:1856, loss:1.858, acc:0.324
# step:1857, loss:1.817, acc:0.318
# step:1858, loss:1.800, acc:0.326
# step:1859, loss:1.880, acc:0.320
# step:1860, loss:1.795, acc:0.330
# step:1861, loss:1.840, acc:0.358
# step:1862, loss:1.833, acc:0.338
# step:1863, loss:1.827, acc:0.334
# step:1864, loss:1.797, acc:0.352
# step:1865, loss:1.827, acc:0.334
# step:1866, loss:1.885, acc:0.324
# step:1867, loss:1.815, acc:0.362
# step:1868, loss:1.854, acc:0.318
# step:1869, loss:1.806, acc:0.360
# step:1870, loss:1.840, acc:0.328
# step:1871, loss:1.869, acc:0.344
# step:1872, loss:1.841, acc:0.310
# step:1873, loss:1.807, acc:0.336
# step:1874, loss:1.862, acc:0.318
# step:1875, loss:1.756, acc:0.348
# step:1876, loss:1.907, acc:0.332
# step:1877, loss:1.810, acc:0.356
# step:1878, loss:1.826, acc:0.328
# step:1879, loss:1.808, acc:0.330
# step:1880, loss:1.830, acc:0.324
# step:1881, loss:1.892, acc:0.300
# step:1882, loss:1.753, acc:0.330
# step:1883, loss:1.785, acc:0.350
# step:1884, loss:1.807, acc:0.350
# step:1885, loss:1.800, acc:0.350
# step:1886, loss:1.919, acc:0.292
# step:1887, loss:1.770, acc:0.340
# step:1888, loss:1.851, acc:0.298
# step:1889, loss:1.881, acc:0.352
# step:1890, loss:1.765, acc:0.368
# step:1891, loss:1.831, acc:0.328
# step:1892, loss:1.833, acc:0.350
# step:1893, loss:1.858, acc:0.342
# step:1894, loss:1.793, acc:0.342
# step:1895, loss:1.901, acc:0.338
# step:1896, loss:1.811, acc:0.354
# step:1897, loss:1.798, acc:0.336
# step:1898, loss:1.838, acc:0.358
# step:1899, loss:1.780, acc:0.328
# step:1900, loss:1.738, acc:0.362
# step:1901, loss:1.757, acc:0.352
# step:1902, loss:1.856, acc:0.316
# step:1903, loss:1.859, acc:0.320
# step:1904, loss:1.849, acc:0.338
# step:1905, loss:1.756, acc:0.328
# step:1906, loss:1.759, acc:0.366
# step:1907, loss:1.830, acc:0.344
# step:1908, loss:1.826, acc:0.348
# step:1909, loss:1.799, acc:0.370
# step:1910, loss:1.805, acc:0.372
# step:1911, loss:1.701, acc:0.376
# step:1912, loss:1.859, acc:0.316
# step:1913, loss:1.766, acc:0.356
# step:1914, loss:1.913, acc:0.304
# step:1915, loss:1.860, acc:0.290
# step:1916, loss:1.852, acc:0.340
# step:1917, loss:1.809, acc:0.330
# step:1918, loss:1.849, acc:0.362
# step:1919, loss:1.827, acc:0.326
# step:1920, loss:1.829, acc:0.328
# step:1921, loss:1.802, acc:0.340
# step:1922, loss:1.877, acc:0.338
# step:1923, loss:1.872, acc:0.330
# step:1924, loss:1.882, acc:0.332
# step:1925, loss:1.805, acc:0.324
# step:1926, loss:1.814, acc:0.374
# step:1927, loss:1.818, acc:0.338
# step:1928, loss:1.820, acc:0.354
# step:1929, loss:1.767, acc:0.360
# step:1930, loss:1.845, acc:0.310
# step:1931, loss:1.816, acc:0.340
# step:1932, loss:1.832, acc:0.354
# step:1933, loss:1.757, acc:0.364
# step:1934, loss:1.796, acc:0.338
# step:1935, loss:1.832, acc:0.330
# step:1936, loss:1.762, acc:0.332
# step:1937, loss:1.797, acc:0.330
# step:1938, loss:1.895, acc:0.324
# step:1939, loss:1.898, acc:0.294
# step:1940, loss:1.855, acc:0.368
# step:1941, loss:1.817, acc:0.310
# step:1942, loss:1.855, acc:0.304
# step:1943, loss:1.881, acc:0.304
# step:1944, loss:1.784, acc:0.326
# step:1945, loss:1.882, acc:0.326
# step:1946, loss:1.830, acc:0.322
# step:1947, loss:1.783, acc:0.370
# step:1948, loss:1.725, acc:0.360
# step:1949, loss:1.885, acc:0.300
# step:1950, loss:1.773, acc:0.340
# step:1951, loss:1.752, acc:0.356
# step:1952, loss:1.788, acc:0.350
# step:1953, loss:1.935, acc:0.328
# step:1954, loss:1.923, acc:0.332
# step:1955, loss:1.738, acc:0.366
# step:1956, loss:1.721, acc:0.364
# step:1957, loss:1.883, acc:0.326
# step:1958, loss:1.774, acc:0.354
# step:1959, loss:1.809, acc:0.376
# step:1960, loss:1.838, acc:0.362
# step:1961, loss:1.881, acc:0.330
# step:1962, loss:1.840, acc:0.314
# step:1963, loss:1.871, acc:0.336
# step:1964, loss:1.878, acc:0.346
# step:1965, loss:1.786, acc:0.374
# step:1966, loss:1.803, acc:0.352
# step:1967, loss:1.858, acc:0.330
# step:1968, loss:1.831, acc:0.340
# step:1969, loss:1.814, acc:0.368
# step:1970, loss:1.823, acc:0.338
# step:1971, loss:1.785, acc:0.364
# step:1972, loss:1.824, acc:0.342
# step:1973, loss:1.800, acc:0.362
# step:1974, loss:1.689, acc:0.396
# step:1975, loss:1.804, acc:0.342
# step:1976, loss:1.901, acc:0.310
# step:1977, loss:1.769, acc:0.360
# step:1978, loss:1.779, acc:0.308
# step:1979, loss:1.822, acc:0.354
# step:1980, loss:1.911, acc:0.312
# step:1981, loss:1.814, acc:0.370
# step:1982, loss:1.762, acc:0.376
# step:1983, loss:1.809, acc:0.338
# step:1984, loss:1.795, acc:0.324
# step:1985, loss:1.853, acc:0.316
# step:1986, loss:1.886, acc:0.318
# step:1987, loss:1.827, acc:0.336
# step:1988, loss:1.823, acc:0.334
# step:1989, loss:1.801, acc:0.346
# step:1990, loss:1.957, acc:0.314
# step:1991, loss:1.662, acc:0.404
# step:1992, loss:1.798, acc:0.342
# step:1993, loss:1.856, acc:0.342
# step:1994, loss:1.792, acc:0.356
# step:1995, loss:1.807, acc:0.334
# step:1996, loss:1.831, acc:0.338
# step:1997, loss:1.813, acc:0.304
# step:1998, loss:1.795, acc:0.348
# step:1999, loss:1.873, acc:0.360
# test acc:[0.43761525]

# %%
import matplotlib.pyplot as plt
from data import load_data
from cnn2 import *
import numpy as np

# 这里各种参数的设置
# input_size 图像的尺寸
# depth 是图像的通道数
# nu_classes 是数据类别
# learning_rate 是学习率
# model_dir 保存模型的地址
input_size = 32
depth = 3
num_classes = 10
learning_rate = 1e-4
model_dir = './svhn_model/model.ckpt'
max_step = 2000

cnn = CNN(input_size, depth, num_classes, learning_rate)
cnn.saver.restore(cnn.sess,model_dir)
# 要显示的源图片
test_file_path = 'test_32x32.mat'
data_x, data_y = load_data(test_file_path)

image = [data_x[6,:,:,:]]

# 要显示的输出
conv_1 = cnn.sess.run([cnn.h_conv1], feed_dict={cnn.x:image, cnn.keep_prob:1.0})[0]
kernel_1 = cnn.sess.run([cnn.W_conv1])[0]


conv_2 = cnn.sess.run([cnn.h_conv2], feed_dict={cnn.x:image, cnn.keep_prob:1.0})[0]
kernel_2 = cnn.sess.run([cnn.W_conv2])[0]


fig = plt.figure()
fig.suptitle("conv_1 and deconv_1")
show_conv1(fig, conv_1, kernel_1, cnn.input_size, depth)
fig = plt.figure()
fig.suptitle("conv_2 and deconv")
show_conv2(fig, conv_2, kernel_1,kernel_2,  cnn.input_size, depth)
# plt.imshow(dst)
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./svhn_model/model.ckpt
# /Users/peiruwu/Desktop/MNIST/cnn2.py:122: RuntimeWarning: invalid value encountered in true_divide
#   return (input_data-np.min(input_data))/(np.max(input_data)-np.min(input_data))
# 64
